# %% [markdown]
# **Step 1: GPU configuration**

# %%
# %%time
# Step 1: GPU configuration
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 4.26 ms, sys: 1 ms, total: 5.26 ms
# Wall time: 105 ms

# %% [markdown]
# **Step 2: Mount Google Drive**

# %%
# Step 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Step 3: Install required packages**

# %%
# !pip install tensorflow_addons
# !pip install visualkeras
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %% [markdown]
# **Step 4: Import libraries**

# %%
import cv2
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf

import warnings
import pandas as pd
from sklearn.utils import class_weight
from collections import Counter

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **Step 5: Define labels and image size**

# %%
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 32

# %% [markdown]
# **Step 6: Function to get data**

# %%
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1]
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %% [markdown]
# **Step 7: Load data**

# %%
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")

# %% [markdown]
# **Step 8: Display total number of training images**

# %%
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))
# Out:
# Total number of training images:  6533

# %% [markdown]
# **Step 9: Create a DataFrame with Filename and ClassId**

# %%
data_df = pd.DataFrame()
data_df['Filename'] = [img_name.split("/")[-1] for img_name in image_names]
data_df['ClassId'] = [img_name.split("/")[-2] for img_name in image_names]

# %% [markdown]
# **Step 10: Display sample images**

# %%
plot_df = data_df.sample(min(9, len(data_df))).reset_index()
plt.figure(figsize=(10, 10))
for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3, 3, i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# **Step 11: Display class distribution**

# %%
class_id_distribution = data_df['ClassId'].value_counts()
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **Step 12: Preprocess and split data**

# %%
X = []
Y = []
for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)

# %% [markdown]
# **Step 13: Split data with stratified sampling**

# %%
# Make sure to import train_test_split
from sklearn.model_selection import train_test_split

# Split data with stratified sampling
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.18, random_state=8)

# %% [markdown]
# **Step 14: Display shapes of train, validation, and test sets**

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 32, 32, 3) - y_train shape: (4820,)
# x_val shape: (1059, 32, 32, 3) - y_val shape: (1059,)
# x_test shape: (654, 32, 32, 3) - y_test shape: (654,)

# %% [markdown]
# **Step 16: Set up model parameters**

# %%
num_classes = 3
input_shape = (32, 32, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250

# %% [markdown]
# **Step 17: Data augmentation**

# %%
# Make sure to import layers
from keras import layers

# Data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(img_size, img_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# **Step 18: Define CNN model**

# %%
def create_cnn_classifier():
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPool2D(2,2),
        Conv2D(64, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Conv2D(128, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %% [markdown]
# **Step 19: Display CNN model summary**

# %%
cnn_classifier = create_cnn_classifier()
cnn_classifier.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 30, 30, 32)        896
#
#  max_pooling2d_18 (MaxPooli  (None, 15, 15, 32)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 64)        18496
#
#  max_pooling2d_19 (MaxPooli  (None, 6, 6, 64)          0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 4, 4, 128)         73856
#
#  max_pooling2d_20 (MaxPooli  (None, 2, 2, 128)         0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 357443 (1.36 MB)
# Trainable params: 357443 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Step 20: Compile CNN model**

# %%
initial_learning_rate = learning_rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=weight_decay, staircase=True
)

cnn_classifier.compile(
    optimizer=Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Step 21: Run CNN experiment**

# %%
# Define early stopping callback
early_stopping_cnn = tf.keras.callbacks.EarlyStopping(
    patience=15,
    verbose=1,
    mode='auto'
)

# %%
# Step x: Define CNN

def run_cnn_experiment(model, early_stopping):
    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[early_stopping]
    )
    return history

# %% [markdown]
# **Step 22: Create and run CNN model**

# %%
# Run CNN experiment
cnn_history = run_cnn_experiment(cnn_classifier, early_stopping_cnn)
test_loss, test_accuracy = cnn_classifier.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/250
# 38/38 [==============================] - 13s 292ms/step - loss: 0.8346 - accuracy: 0.6083 - val_loss: 0.6293 - val_accuracy: 0.7167
# Epoch 2/250
# 38/38 [==============================] - 14s 361ms/step - loss: 0.4680 - accuracy: 0.8210 - val_loss: 0.3951 - val_accuracy: 0.8366
# Epoch 3/250
# 38/38 [==============================] - 14s 369ms/step - loss: 0.3197 - accuracy: 0.8743 - val_loss: 0.2972 - val_accuracy: 0.8857
# Epoch 4/250
# 38/38 [==============================] - 9s 223ms/step - loss: 0.2429 - accuracy: 0.9058 - val_loss: 0.2368 - val_accuracy: 0.9103
# Epoch 5/250
# 38/38 [==============================] - 7s 195ms/step - loss: 0.1735 - accuracy: 0.9394 - val_loss: 0.1661 - val_accuracy: 0.9348
# Epoch 6/250
# 38/38 [==============================] - 5s 142ms/step - loss: 0.1249 - accuracy: 0.9575 - val_loss: 0.1251 - val_accuracy: 0.9622
# Epoch 7/250
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0815 - accuracy: 0.9741 - val_loss: 0.1156 - val_accuracy: 0.9613
# Epoch 8/250
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0748 - accuracy: 0.9759 - val_loss: 0.0924 - val_accuracy: 0.9754
# Epoch 9/250
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0505 - accuracy: 0.9859 - val_loss: 0.0854 - val_accuracy: 0.9745
# Epoch 10/250
# 38/38 [==============================] - 8s 209ms/step - loss: 0.0446 - accuracy: 0.9855 - val_loss: 0.0495 - val_accuracy: 0.9858
# Epoch 11/250
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0311 - accuracy: 0.9902 - val_loss: 0.0518 - val_accuracy: 0.9858
# Epoch 12/250
# 38/38 [==============================] - 6s 166ms/step - loss: 0.0196 - accuracy: 0.9948 - val_loss: 0.0376 - val_accuracy: 0.9877
# Epoch 13/250
# 38/38 [==============================] - 7s 181ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.0526 - val_accuracy: 0.9877
# Epoch 14/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0171 - accuracy: 0.9965 - val_loss: 0.0365 - val_accuracy: 0.9858
# Epoch 15/250
# 38/38 [==============================] - 8s 212ms/step - loss: 0.0101 - accuracy: 0.9979 - val_loss: 0.0423 - val_accuracy: 0.9877
# Epoch 16/250
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.0440 - val_accuracy: 0.9849
# Epoch 17/250
# 38/38 [==============================] - 6s 163ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.0371 - val_accuracy: 0.9906
# Epoch 18/250
# 38/38 [==============================] - 8s 202ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.0332 - val_accuracy: 0.9906
# Epoch 19/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0353 - val_accuracy: 0.9896
# Epoch 20/250
# 38/38 [==============================] - 8s 209ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.0273 - val_accuracy: 0.9877
# Epoch 21/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0374 - val_accuracy: 0.9877
# Epoch 22/250
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0472 - val_accuracy: 0.9821
# Epoch 23/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0298 - val_accuracy: 0.9896
# Epoch 24/250
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9887
# Epoch 25/250
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9868
# Epoch 26/250
# 38/38 [==============================] - 5s 142ms/step - loss: 7.9679e-04 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9877
# Epoch 27/250
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9896
# Epoch 28/250
# 38/38 [==============================] - 7s 180ms/step - loss: 9.0401e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9896
# Epoch 29/250
# 38/38 [==============================] - 5s 142ms/step - loss: 6.5952e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9896
# Epoch 30/250
# 38/38 [==============================] - 8s 217ms/step - loss: 5.0704e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9906
# Epoch 31/250
# 38/38 [==============================] - 5s 142ms/step - loss: 3.7068e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9915
# Epoch 32/250
# 38/38 [==============================] - 6s 169ms/step - loss: 4.0650e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9915
# Epoch 33/250
# 38/38 [==============================] - 7s 180ms/step - loss: 4.2581e-04 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9906
# Epoch 34/250
# 38/38 [==============================] - 7s 176ms/step - loss: 4.0543e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9915
# Epoch 35/250
# 38/38 [==============================] - 8s 207ms/step - loss: 3.6916e-04 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9915
# Epoch 35: early stopping
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0735 - accuracy: 0.9817
# Test Accuracy: 98.17%

# %% [markdown]
# **Step 23: Plot training and validation metrics**

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer: Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Step 24: Evaluate CNN model on validation set**

# %%
cnn_predictions = cnn_classifier.predict(x_val)
cnn_y_pred = [np.argmax(probas) for probas in cnn_predictions]
# Out:
# 34/34 [==============================] - 1s 19ms/step

# %%
def plot_confusion_matrix_support(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    The values displayed are the actual support values.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    for i in range(len(classes)):
        for j in range(len(classes)):
            plt.text(j, i, f"{cm[i, j]:.0f}",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > np.max(cm) / 2 else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# **Step 25: Plot normalized confusion matrix for validation set**

# %%
# Step 25: Plot normalized confusion matrix for validation set

# Compute confusion matrix for validation set
cnf_matrix_cnn = confusion_matrix(y_val, cnn_y_pred)


# Plot confusion matrix for validation set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn, classes=labels, title='Confusion matrix (CNN - Validation)')
plt.show()

# Print the confusion matrix to verify the values
print("Confusion Matrix:")
print(cnf_matrix_cnn)
# Out:
# Confusion Matrix:
# [[305   0   0]
#  [  0 329   4]
#  [  0   5 416]]

# %% [markdown]
# **Step 26: Display classification report for validation set**

# %%
print(classification_report(y_val, cnn_y_pred, target_names=labels))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       305
#          Downy Mildew       0.99      0.99      0.99       333
#             Leaf Spot       0.99      0.99      0.99       421
#
#              accuracy                           0.99      1059
#             macro avg       0.99      0.99      0.99      1059
#          weighted avg       0.99      0.99      0.99      1059

# %% [markdown]
# **Step 27: Evaluate CNN model on test set**

# %%
cnn_predictions_test = cnn_classifier.predict(x_test)
cnn_y_pred_test = [np.argmax(probas) for probas in cnn_predictions_test]
# Out:
# 21/21 [==============================] - 0s 21ms/step

# %% [markdown]
# **Step 28: Plot normalized confusion matrix for test set**

# %%
# Compute confusion matrix for test set
cnf_matrix_cnn_test = confusion_matrix(y_test, cnn_y_pred_test)

# Print the confusion matrix to verify the values


# Plot confusion matrix for test set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn_test, classes=labels, title='Confusion matrix (CNN - Test)')
plt.show()
print("Confusion Matrix (Test):")
print(cnf_matrix_cnn_test)
# Out:
# Confusion Matrix (Test):
# [[199   0   1]
#  [  0 197   6]
#  [  0   5 246]]

# %% [markdown]
# **Step 29: Display classification report for test set**

# %%
print(classification_report(y_test, cnn_y_pred_test, target_names=labels))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      0.99      1.00       200
#          Downy Mildew       0.98      0.97      0.97       203
#             Leaf Spot       0.97      0.98      0.98       251
#
#              accuracy                           0.98       654
#             macro avg       0.98      0.98      0.98       654
#          weighted avg       0.98      0.98      0.98       654
