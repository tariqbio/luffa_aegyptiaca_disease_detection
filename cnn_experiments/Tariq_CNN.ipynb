# %% [markdown]
# **Step 1: GPU configuration**

# %%
# %%time
# Step 1: GPU configuration
# !nvidia-smi
# Out:
# Tue Jun  4 04:55:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   60C    P0              27W /  70W |   1131MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2075      C   ...le/drive/directoryprefetcher_binary     1128MiB |
# +---------------------------------------------------------------------------------------+
# CPU times: user 2.11 ms, sys: 2.92 ms, total: 5.03 ms
# Wall time: 105 ms

# %% [markdown]
# **Step 2: Mount Google Drive**

# %%
# Step 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Step 3: Install required packages**

# %%
# !pip install tensorflow_addons
# !pip install visualkeras
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.25.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18.post0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %% [markdown]
# **Step 4: Import libraries**

# %%
import cv2
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf

import warnings
import pandas as pd
from sklearn.utils import class_weight
from collections import Counter

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **Step 5: Define labels and image size**

# %%
labels = ["Mosaic Disease", "Insect Infestation"]
img_size = 32

# %% [markdown]
# **Step 6: Function to get data**

# %%
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)

        # Loop through images in the current label's directory
        for img in os.listdir(path):
            try:
                # Read and convert the image to RGB format
                img_arr = cv2.imread(os.path.join(path, img))[..., ::-1]

                # Resize the image to the preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size))

                # Append the resized image and its class number to the data list
                data.append([resized_arr, class_num])
            except Exception as e:
                print(f"Error reading or processing image {img} in {label} category: {e}")

    return data

# %% [markdown]
# **Step 7: Load data**

# %%
data_dir = get_data("/content/drive/MyDrive/Luffa/Luffa Dataset")

# %% [markdown]
# **Step 8: Display total number of training images**

# %%
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa/Luffa Dataset', '*', '*'))
print("Total number of training images: ", len(image_names))
# Out:
# Total number of training images:  6226

# %% [markdown]
# **Step 9: Create a DataFrame with Filename and ClassId**

# %%
data_df = pd.DataFrame()
data_df['Filename'] = [img_name.split("/")[-1] for img_name in image_names]
data_df['ClassId'] = [img_name.split("/")[-2] for img_name in image_names]

# %% [markdown]
# **Step 10: Display sample images**

# %%
plot_df = data_df.sample(min(9, len(data_df))).reset_index()
plt.figure(figsize=(10, 10))
for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3, 3, i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa/Luffa Dataset', label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# **Step 11: Display class distribution**

# %%
class_id_distribution = data_df['ClassId'].value_counts()
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **Step 12: Preprocess and split data**

# %%
X = []
Y = []
for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)

# %% [markdown]
# **Step 13: Split data with stratified sampling**

# %%
# Make sure to import train_test_split
from sklearn.model_selection import train_test_split

# Split data with stratified sampling
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.18, random_state=8)

# %% [markdown]
# **Step 14: Display shapes of train, validation, and test sets**

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4594, 32, 32, 3) - y_train shape: (4594,)
# x_val shape: (1009, 32, 32, 3) - y_val shape: (1009,)
# x_test shape: (623, 32, 32, 3) - y_test shape: (623,)

# %% [markdown]
# **Step 16: Set up model parameters**

# %%
num_classes = 2
input_shape = (32, 32, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250

# %% [markdown]
# **Step 17: Data augmentation**

# %%
# Make sure to import layers
from keras import layers

# Data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(img_size, img_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# **Step 18: Define CNN model**

# %%
def create_cnn_classifier():
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPool2D(2,2),
        Conv2D(64, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Conv2D(128, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %% [markdown]
# **Step 19: Display CNN model summary**

# %%
cnn_classifier = create_cnn_classifier()
cnn_classifier.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 356930 (1.36 MB)
# Trainable params: 356930 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Step 20: Compile CNN model**

# %%
initial_learning_rate = learning_rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=weight_decay, staircase=True
)

cnn_classifier.compile(
    optimizer=Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Step 21: Run CNN experiment**

# %%
# Define early stopping callback
early_stopping_cnn = tf.keras.callbacks.EarlyStopping(
    patience=15,
    verbose=1,
    mode='auto'
)

# %%
# Step x: Define CNN

def run_cnn_experiment(model, early_stopping):
    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[early_stopping]
    )
    return history

# %% [markdown]
# **Step 22: Create and run CNN model**

# %%
# Run CNN experiment
cnn_history = run_cnn_experiment(cnn_classifier, early_stopping_cnn)
test_loss, test_accuracy = cnn_classifier.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/250
# 36/36 [==============================] - 9s 39ms/step - loss: 0.5658 - accuracy: 0.6824 - val_loss: 0.4259 - val_accuracy: 0.8206
# Epoch 2/250
# 36/36 [==============================] - 0s 9ms/step - loss: 0.3517 - accuracy: 0.8468 - val_loss: 0.2690 - val_accuracy: 0.8910
# Epoch 3/250
# 36/36 [==============================] - 0s 12ms/step - loss: 0.2548 - accuracy: 0.8925 - val_loss: 0.2661 - val_accuracy: 0.8900
# Epoch 4/250
# 36/36 [==============================] - 0s 11ms/step - loss: 0.1981 - accuracy: 0.9182 - val_loss: 0.2271 - val_accuracy: 0.9078
# Epoch 5/250
# 36/36 [==============================] - 0s 12ms/step - loss: 0.1486 - accuracy: 0.9451 - val_loss: 0.1226 - val_accuracy: 0.9554
# Epoch 6/250
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0933 - accuracy: 0.9667 - val_loss: 0.0905 - val_accuracy: 0.9732
# Epoch 7/250
# 36/36 [==============================] - 0s 10ms/step - loss: 0.1064 - accuracy: 0.9578 - val_loss: 0.0887 - val_accuracy: 0.9722
# Epoch 8/250
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0589 - accuracy: 0.9819 - val_loss: 0.0663 - val_accuracy: 0.9832
# Epoch 9/250
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0771 - accuracy: 0.9715 - val_loss: 0.0726 - val_accuracy: 0.9792
# Epoch 10/250
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.0616 - val_accuracy: 0.9832
# Epoch 11/250
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 0.9898 - val_loss: 0.0734 - val_accuracy: 0.9802
# Epoch 12/250
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0218 - accuracy: 0.9939 - val_loss: 0.0464 - val_accuracy: 0.9861
# Epoch 13/250
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0482 - val_accuracy: 0.9861
# Epoch 14/250
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0504 - val_accuracy: 0.9861
# Epoch 15/250
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0128 - accuracy: 0.9967 - val_loss: 0.0464 - val_accuracy: 0.9881
# Epoch 16/250
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 0.9996 - val_loss: 0.0480 - val_accuracy: 0.9881
# Epoch 17/250
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.0455 - val_accuracy: 0.9891
# Epoch 18/250
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0041 - accuracy: 0.9996 - val_loss: 0.0542 - val_accuracy: 0.9901
# Epoch 19/250
# 36/36 [==============================] - 0s 12ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0471 - val_accuracy: 0.9901
# Epoch 20/250
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9881
# Epoch 21/250
# 36/36 [==============================] - 0s 13ms/step - loss: 9.9838e-04 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9911
# Epoch 22/250
# 36/36 [==============================] - 1s 16ms/step - loss: 8.1026e-04 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9911
# Epoch 23/250
# 36/36 [==============================] - 1s 18ms/step - loss: 7.6327e-04 - accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 0.9911
# Epoch 24/250
# 36/36 [==============================] - 1s 17ms/step - loss: 5.8169e-04 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9881
# Epoch 25/250
# 36/36 [==============================] - 1s 22ms/step - loss: 4.9014e-04 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9871
# Epoch 26/250
# 36/36 [==============================] - 1s 22ms/step - loss: 4.1422e-04 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9891
# Epoch 27/250
# 36/36 [==============================] - 1s 25ms/step - loss: 4.2237e-04 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9881
# Epoch 28/250
# 36/36 [==============================] - 1s 19ms/step - loss: 3.6224e-04 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9891
# Epoch 29/250
# 36/36 [==============================] - 1s 17ms/step - loss: 3.4582e-04 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9891
# Epoch 30/250
# 36/36 [==============================] - 1s 14ms/step - loss: 2.6672e-04 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 0.9881
# Epoch 31/250
# 36/36 [==============================] - 0s 13ms/step - loss: 2.3519e-04 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9881
# Epoch 32/250
# 36/36 [==============================] - 0s 13ms/step - loss: 2.4095e-04 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9871
# Epoch 32: early stopping
# 20/20 [==============================] - 1s 21ms/step - loss: 0.0445 - accuracy: 0.9920
# Test Accuracy: 99.20%

# %% [markdown]
# **Step 23: Plot training and validation metrics**

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer: Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Step 24: Evaluate CNN model on validation set**

# %%
cnn_predictions = cnn_classifier.predict(x_val)
cnn_y_pred = [np.argmax(probas) for probas in cnn_predictions]
# Out:
# 32/32 [==============================] - 1s 21ms/step

# %%
def plot_confusion_matrix_support(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    The values displayed are the actual support values.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    for i in range(len(classes)):
        for j in range(len(classes)):
            plt.text(j, i, f"{cm[i, j]:.0f}",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > np.max(cm) / 2 else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# **Step 25: Plot normalized confusion matrix for validation set**

# %%
# Step 25: Plot normalized confusion matrix for validation set

# Compute confusion matrix for validation set
cnf_matrix_cnn = confusion_matrix(y_val, cnn_y_pred)


# Plot confusion matrix for validation set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn, classes=labels, title='Confusion matrix (CNN - Validation)')
plt.show()

# Print the confusion matrix to verify the values
print("Confusion Matrix:")
print(cnf_matrix_cnn)
# Out:
# Confusion Matrix:
# [[579   7]
#  [  6 417]]

# %% [markdown]
# **Step 26: Display classification report for validation set**

# %%
print(classification_report(y_val, cnn_y_pred, target_names=labels))
# Out:
#                     precision    recall  f1-score   support
#
#     Mosaic Disease       0.99      0.99      0.99       586
# Insect Infestation       0.98      0.99      0.98       423
#
#           accuracy                           0.99      1009
#          macro avg       0.99      0.99      0.99      1009
#       weighted avg       0.99      0.99      0.99      1009

# %% [markdown]
# **Step 27: Evaluate CNN model on test set**

# %%
cnn_predictions_test = cnn_classifier.predict(x_test)
cnn_y_pred_test = [np.argmax(probas) for probas in cnn_predictions_test]
# Out:
# 20/20 [==============================] - 0s 3ms/step

# %% [markdown]
# **Step 28: Plot normalized confusion matrix for test set**

# %%
# Compute confusion matrix for test set
cnf_matrix_cnn_test = confusion_matrix(y_test, cnn_y_pred_test)

# Print the confusion matrix to verify the values


# Plot confusion matrix for test set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn_test, classes=labels, title='Confusion matrix (CNN - Test)')
plt.show()
print("Confusion Matrix (Test):")
print(cnf_matrix_cnn_test)
# Out:
# Confusion Matrix (Test):
# [[370   2]
#  [  3 248]]

# %% [markdown]
# **Step 29: Display classification report for test set**

# %%
print(classification_report(y_test, cnn_y_pred_test, target_names=labels))
# Out:
#                     precision    recall  f1-score   support
#
#     Mosaic Disease       0.99      0.99      0.99       372
# Insect Infestation       0.99      0.99      0.99       251
#
#           accuracy                           0.99       623
#          macro avg       0.99      0.99      0.99       623
#       weighted avg       0.99      0.99      0.99       623

# %%
# Replace the path below with the actual path to your new image in Google Drive
new_image_path = '/content/drive/MyDrive/Predicting Image/Leaf-Spot (47).jpg'

# Load and preprocess the new image
new_image = cv2.imread(new_image_path)[...,::-1]  # Convert BGR to RGB format
resized_image = cv2.resize(new_image, (img_size, img_size))
input_image = np.expand_dims(resized_image, axis=0) / 255.0  # Normalize

# Use the trained model to make predictions
predictions = cnn_classifier.predict(input_image)
predicted_label = labels[np.argmax(predictions)]

# Display the original image along with the predicted label
plt.figure(figsize=(6, 6))
plt.imshow(resized_image)
plt.title(f"Predicted Label: {predicted_label}")
plt.axis("off")
plt.show()
# Out:
# 1/1 [==============================] - 1s 515ms/step
