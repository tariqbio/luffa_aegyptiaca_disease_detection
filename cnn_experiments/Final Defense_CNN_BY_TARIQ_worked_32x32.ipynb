# %% [markdown]
# **Step 1: GPU configuration**

# %%
# %%time
# Step 1: GPU configuration
# !nvidia-smi
# Out:
# Tue Jan  2 19:15:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# CPU times: user 11.1 ms, sys: 0 ns, total: 11.1 ms
# Wall time: 109 ms

# %% [markdown]
# **Step 2: Mount Google Drive**

# %%
# Step 2: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Step 3: Install required packages**

# %%
# !pip install tensorflow_addons
# !pip install visualkeras
# !pip install -U tensorflow-addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 14.0 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %% [markdown]
# **Step 4: Import libraries**

# %%
import cv2
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf

import warnings
import pandas as pd
from sklearn.utils import class_weight
from collections import Counter

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **Step 5: Define labels and image size**

# %%
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 32

# %% [markdown]
# **Step 6: Function to get data**

# %%
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1]
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %% [markdown]
# **Step 7: Load data**

# %%
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")

# %% [markdown]
# **Step 8: Display total number of training images**

# %%
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))
# Out:
# Total number of training images:  6533

# %% [markdown]
# **Step 9: Create a DataFrame with Filename and ClassId**

# %%
data_df = pd.DataFrame()
data_df['Filename'] = [img_name.split("/")[-1] for img_name in image_names]
data_df['ClassId'] = [img_name.split("/")[-2] for img_name in image_names]

# %% [markdown]
# **Step 10: Display sample images**

# %%
plot_df = data_df.sample(min(9, len(data_df))).reset_index()
plt.figure(figsize=(10, 10))
for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3, 3, i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# **Step 11: Display class distribution**

# %%
class_id_distribution = data_df['ClassId'].value_counts()
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **Step 12: Preprocess and split data**

# %%
X = []
Y = []
for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)

# %% [markdown]
# **Step 13: Split data with stratified sampling**

# %%
# Make sure to import train_test_split
from sklearn.model_selection import train_test_split

# Split data with stratified sampling
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.18, random_state=8)

# %% [markdown]
# **Step 14: Display shapes of train, validation, and test sets**

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 32, 32, 3) - y_train shape: (4820,)
# x_val shape: (1059, 32, 32, 3) - y_val shape: (1059,)
# x_test shape: (654, 32, 32, 3) - y_test shape: (654,)

# %% [markdown]
# **Step 16: Set up model parameters**

# %%
num_classes = 3
input_shape = (32, 32, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250

# %% [markdown]
# **Step 17: Data augmentation**

# %%
# Make sure to import layers
from keras import layers

# Data augmentation
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(img_size, img_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# **Step 18: Define CNN model**

# %%
def create_cnn_classifier():
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        MaxPool2D(2,2),
        Conv2D(64, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Conv2D(128, (3,3), activation='relu'),
        MaxPool2D(2,2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %% [markdown]
# **Step 19: Display CNN model summary**

# %%
cnn_classifier = create_cnn_classifier()
cnn_classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 357443 (1.36 MB)
# Trainable params: 357443 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Step 20: Compile CNN model**

# %%
initial_learning_rate = learning_rate
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=weight_decay, staircase=True
)

cnn_classifier.compile(
    optimizer=Adam(learning_rate=lr_schedule),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Step 21: Run CNN experiment**

# %%
# Define early stopping callback
early_stopping_cnn = tf.keras.callbacks.EarlyStopping(
    patience=15,
    verbose=1,
    mode='auto'
)

# %%
# Step x: Define CNN

def run_cnn_experiment(model, early_stopping):
    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[early_stopping]
    )
    return history

# %% [markdown]
# **Step 22: Create and run CNN model**

# %%
# Run CNN experiment
cnn_history = run_cnn_experiment(cnn_classifier, early_stopping_cnn)
test_loss, test_accuracy = cnn_classifier.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/250
# 38/38 [==============================] - 6s 30ms/step - loss: 0.8745 - accuracy: 0.5871 - val_loss: 0.5696 - val_accuracy: 0.7941
# Epoch 2/250
# 38/38 [==============================] - 0s 9ms/step - loss: 0.4992 - accuracy: 0.8058 - val_loss: 0.4303 - val_accuracy: 0.8404
# Epoch 3/250
# 38/38 [==============================] - 0s 10ms/step - loss: 0.3596 - accuracy: 0.8556 - val_loss: 0.3082 - val_accuracy: 0.8763
# Epoch 4/250
# 38/38 [==============================] - 0s 9ms/step - loss: 0.2619 - accuracy: 0.8950 - val_loss: 0.2540 - val_accuracy: 0.9027
# Epoch 5/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1879 - accuracy: 0.9320 - val_loss: 0.1683 - val_accuracy: 0.9415
# Epoch 6/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1353 - accuracy: 0.9556 - val_loss: 0.1399 - val_accuracy: 0.9528
# Epoch 7/250
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1269 - accuracy: 0.9577 - val_loss: 0.1008 - val_accuracy: 0.9660
# Epoch 8/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0949 - accuracy: 0.9691 - val_loss: 0.0822 - val_accuracy: 0.9736
# Epoch 9/250
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0708 - accuracy: 0.9759 - val_loss: 0.0675 - val_accuracy: 0.9792
# Epoch 10/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0522 - accuracy: 0.9838 - val_loss: 0.0612 - val_accuracy: 0.9811
# Epoch 11/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0422 - accuracy: 0.9880 - val_loss: 0.0521 - val_accuracy: 0.9811
# Epoch 12/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0927 - accuracy: 0.9666 - val_loss: 0.0691 - val_accuracy: 0.9773
# Epoch 13/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0544 - accuracy: 0.9824 - val_loss: 0.0517 - val_accuracy: 0.9802
# Epoch 14/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.0341 - val_accuracy: 0.9858
# Epoch 15/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.0319 - val_accuracy: 0.9858
# Epoch 16/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 0.9956 - val_loss: 0.0344 - val_accuracy: 0.9868
# Epoch 17/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0118 - accuracy: 0.9971 - val_loss: 0.0285 - val_accuracy: 0.9906
# Epoch 18/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0236 - accuracy: 0.9913 - val_loss: 0.0361 - val_accuracy: 0.9858
# Epoch 19/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0217 - val_accuracy: 0.9906
# Epoch 20/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.0210 - val_accuracy: 0.9906
# Epoch 21/250
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0233 - val_accuracy: 0.9906
# Epoch 22/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.0215 - val_accuracy: 0.9906
# Epoch 23/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0213 - val_accuracy: 0.9896
# Epoch 24/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0263 - val_accuracy: 0.9887
# Epoch 25/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0176 - val_accuracy: 0.9934
# Epoch 26/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0207 - val_accuracy: 0.9896
# Epoch 27/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9953
# Epoch 28/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0156 - val_accuracy: 0.9943
# Epoch 29/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9953
# Epoch 30/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9953
# Epoch 31/250
# 38/38 [==============================] - 0s 7ms/step - loss: 9.0073e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9943
# Epoch 32/250
# 38/38 [==============================] - 0s 7ms/step - loss: 7.7559e-04 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9953
# Epoch 33/250
# 38/38 [==============================] - 0s 6ms/step - loss: 7.4859e-04 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9943
# Epoch 34/250
# 38/38 [==============================] - 0s 6ms/step - loss: 6.8477e-04 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9915
# Epoch 35/250
# 38/38 [==============================] - 0s 6ms/step - loss: 4.7020e-04 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9924
# Epoch 36/250
# 38/38 [==============================] - 0s 7ms/step - loss: 8.4972e-04 - accuracy: 0.9998 - val_loss: 0.0185 - val_accuracy: 0.9924
# Epoch 37/250
# 38/38 [==============================] - 0s 6ms/step - loss: 5.1986e-04 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9943
# Epoch 38/250
# 38/38 [==============================] - 0s 7ms/step - loss: 4.4184e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9915
# Epoch 39/250
# 38/38 [==============================] - 0s 6ms/step - loss: 4.4347e-04 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9962
# Epoch 40/250
# 38/38 [==============================] - 0s 7ms/step - loss: 3.8572e-04 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9943
# Epoch 41/250
# 38/38 [==============================] - 0s 8ms/step - loss: 5.3408e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9953
# Epoch 42/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.9102 - accuracy: 0.7882 - val_loss: 0.3346 - val_accuracy: 0.8820
# Epoch 43/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.1558 - accuracy: 0.9467 - val_loss: 0.0951 - val_accuracy: 0.9717
# Epoch 44/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0478 - accuracy: 0.9882 - val_loss: 0.0592 - val_accuracy: 0.9830
# Epoch 45/250
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0475 - val_accuracy: 0.9849
# Epoch 46/250
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0412 - accuracy: 0.9849 - val_loss: 0.0679 - val_accuracy: 0.9792
# Epoch 46: early stopping
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0419 - accuracy: 0.9862
# Test Accuracy: 98.62%

# %% [markdown]
# **Step 23: Plot training and validation metrics**

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer: Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Step 24: Evaluate CNN model on validation set**

# %%
cnn_predictions = cnn_classifier.predict(x_val)
cnn_y_pred = [np.argmax(probas) for probas in cnn_predictions]
# Out:
# 34/34 [==============================] - 0s 7ms/step

# %%
def plot_confusion_matrix_support(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    The values displayed are the actual support values.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    for i in range(len(classes)):
        for j in range(len(classes)):
            plt.text(j, i, f"{cm[i, j]:.0f}",
                     horizontalalignment="center",
                     color="white" if cm[i, j] > np.max(cm) / 2 else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# **Step 25: Plot normalized confusion matrix for validation set**

# %%
# Step 25: Plot normalized confusion matrix for validation set

# Compute confusion matrix for validation set
cnf_matrix_cnn = confusion_matrix(y_val, cnn_y_pred)


# Plot confusion matrix for validation set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn, classes=labels, title='Confusion matrix (CNN - Validation)')
plt.show()

# Print the confusion matrix to verify the values
print("Confusion Matrix:")
print(cnf_matrix_cnn)
# Out:
# Confusion Matrix:
# [[299   0   6]
#  [  0 318  15]
#  [  0   1 420]]

# %% [markdown]
# **Step 26: Display classification report for validation set**

# %%
print(classification_report(y_val, cnn_y_pred, target_names=labels))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      0.98      0.99       305
#          Downy Mildew       1.00      0.95      0.98       333
#             Leaf Spot       0.95      1.00      0.97       421
#
#              accuracy                           0.98      1059
#             macro avg       0.98      0.98      0.98      1059
#          weighted avg       0.98      0.98      0.98      1059

# %% [markdown]
# **Step 27: Evaluate CNN model on test set**

# %%
cnn_predictions_test = cnn_classifier.predict(x_test)
cnn_y_pred_test = [np.argmax(probas) for probas in cnn_predictions_test]
# Out:
# 21/21 [==============================] - 0s 3ms/step

# %% [markdown]
# **Step 28: Plot normalized confusion matrix for test set**

# %%
# Compute confusion matrix for test set
cnf_matrix_cnn_test = confusion_matrix(y_test, cnn_y_pred_test)

# Print the confusion matrix to verify the values


# Plot confusion matrix for test set based on support
plt.figure()
plot_confusion_matrix_support(cnf_matrix_cnn_test, classes=labels, title='Confusion matrix (CNN - Test)')
plt.show()
print("Confusion Matrix (Test):")
print(cnf_matrix_cnn_test)
# Out:
# Confusion Matrix (Test):
# [[199   0   1]
#  [  0 195   8]
#  [  0   0 251]]

# %% [markdown]
# **Step 29: Display classification report for test set**

# %%
print(classification_report(y_test, cnn_y_pred_test, target_names=labels))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      0.99      1.00       200
#          Downy Mildew       1.00      0.96      0.98       203
#             Leaf Spot       0.97      1.00      0.98       251
#
#              accuracy                           0.99       654
#             macro avg       0.99      0.99      0.99       654
#          weighted avg       0.99      0.99      0.99       654

# %%
# Replace the path below with the actual path to your new image in Google Drive
new_image_path = '/content/drive/MyDrive/Predicting Image/Leaf-Spot (47).jpg'

# Load and preprocess the new image
new_image = cv2.imread(new_image_path)[...,::-1]  # Convert BGR to RGB format
resized_image = cv2.resize(new_image, (img_size, img_size))
input_image = np.expand_dims(resized_image, axis=0) / 255.0  # Normalize

# Use the trained model to make predictions
predictions = cnn_classifier.predict(input_image)
predicted_label = labels[np.argmax(predictions)]

# Display the original image along with the predicted label
plt.figure(figsize=(6, 6))
plt.imshow(resized_image)
plt.title(f"Predicted Label: {predicted_label}")
plt.axis("off")
plt.show()
# Out:
# 1/1 [==============================] - 0s 420ms/step
