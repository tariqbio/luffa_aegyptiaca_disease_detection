# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 7.16 ms, sys: 4 µs, total: 7.17 ms
# Wall time: 107 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CPU times: user 99.6 ms, sys: 14.4 ms, total: 114 ms
# Wall time: 12.8 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# CPU times: user 102 ms, sys: 12.8 ms, total: 115 ms
# Wall time: 12.6 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18)
# CPU times: user 58.6 ms, sys: 4.04 ms, total: 62.7 ms
# Wall time: 7.14 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 14 µs, sys: 0 ns, total: 14 µs
# Wall time: 17.4 µs

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 120 µs, sys: 0 ns, total: 120 µs
# Wall time: 126 µs

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# CPU times: user 4.94 ms, sys: 0 ns, total: 4.94 ms
# Wall time: 15.7 ms

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 10 µs, sys: 1 µs, total: 11 µs
# Wall time: 14.5 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 64
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 8 µs, sys: 0 ns, total: 8 µs
# Wall time: 11.9 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")
# Out:
# CPU times: user 32.3 s, sys: 1.64 s, total: 34 s
# Wall time: 1min 8s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 23 µs, sys: 1e+03 ns, total: 24 µs
# Wall time: 28.8 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6533
# CPU times: user 62.7 ms, sys: 893 µs, total: 63.6 ms
# Wall time: 149 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 13.7 ms, sys: 0 ns, total: 13.7 ms
# Wall time: 13.7 ms
#                    Filename       ClassId
# 0  Downey-Mildew (1754).jpg  Downy Mildew
# 1   Downey-Mildew (257).jpg  Downy Mildew
# 2  Downey-Mildew (1751).jpg  Downy Mildew
# 3  Downey-Mildew (1747).jpg  Downy Mildew
# 4  Downey-Mildew (1265).jpg  Downy Mildew

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 211 ms, sys: 5.89 ms, total: 217 ms
# Wall time: 240 ms

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 4.09 ms, sys: 4 µs, total: 4.09 ms
# Wall time: 7.03 ms
# Leaf Spot                2505
# Downy Mildew             2024
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 122 ms, sys: 4.02 ms, total: 126 ms
# Wall time: 224 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 30.3 ms, sys: 945 µs, total: 31.3 ms
# Wall time: 43.3 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 124 ms, sys: 211 ms, total: 335 ms
# Wall time: 496 ms

# %%
# %%time
print(X.shape)
# Out:
# (6533, 64, 64, 3)
# CPU times: user 866 µs, sys: 3 µs, total: 869 µs
# Wall time: 2.21 ms

# %%
# %%time
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 90.1 ms, sys: 476 ms, total: 566 ms
# Wall time: 580 ms

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 69.9 ms, sys: 348 ms, total: 418 ms
# Wall time: 417 ms

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 64, 64, 3) - y_train shape: (4820,)
# x_val shape: (1059, 64, 64, 3) - y_val shape: (1059,)
# x_test shape: (654, 64, 64, 3) - y_test shape: (654,)
# CPU times: user 1.29 ms, sys: 976 µs, total: 2.27 ms
# Wall time: 2.32 ms

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 211 ms, sys: 18.7 ms, total: 229 ms
# Wall time: 16.4 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 41 µs, sys: 1e+03 ns, total: 42 µs
# Wall time: 45.8 µs

# %%
# %%time
num_classes = 3
input_shape = (64, 64, 3)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.11 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 64  # We'll resize input images to this size
patch_size = 12  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 6
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 9 µs, sys: 0 ns, total: 9 µs
# Wall time: 12.4 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 1.47 s, sys: 935 ms, total: 2.4 s
# Wall time: 2.71 s

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 43 µs, sys: 1e+03 ns, total: 44 µs
# Wall time: 48.4 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 64 X 64
# Patch size: 12 X 12
# Patches per image: 25
# Elements per patch: 432
# CPU times: user 1.2 s, sys: 69 ms, total: 1.27 s
# Wall time: 1.27 s

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 57 µs, sys: 2 µs, total: 59 µs
# Wall time: 64.1 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 8 µs, sys: 0 ns, total: 8 µs
# Wall time: 11.4 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 10.7 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x788e902bf220>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x788e902bf220>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x788e902bf220>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x788e902bf220>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x788e902be080>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x788e902be080>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x788e902be080>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x788e902be080>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patches_3 (Patches)         (None, None, 432)            0         ['data_augmentation[0][0]']
#
#  patch_encoder_1 (PatchEnco  (None, 25, 64)               29312     ['patches_3[0][0]']
#  der)
#
#  layer_normalization_3 (Lay  (None, 25, 64)               128       ['patch_encoder_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 25, 64)               99520     ['layer_normalization_3[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_3[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 25, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'patch_encoder_1[0][0]']
#
#  layer_normalization_4 (Lay  (None, 25, 64)               128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 25, 128)              8320      ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 25, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 25, 64)               8256      ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)         (None, 25, 64)               0         ['dense_8[0][0]']
#
#  add_3 (Add)                 (None, 25, 64)               0         ['dropout_6[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_5 (Lay  (None, 25, 64)               128       ['add_3[0][0]']
#  erNormalization)
#
#  flatten_1 (Flatten)         (None, 1600)                 0         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 1600)                 0         ['flatten_1[0][0]']
#
#  dense_9 (Dense)             (None, 2048)                 3278848   ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)         (None, 2048)                 0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024)                 2098176   ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024)                 0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 3)                    3075      ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 5525898 (21.08 MB)
# Trainable params: 5525891 (21.08 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 34s 826ms/step - loss: 1.1950 - accuracy: 0.6241 - top-5-accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.7517 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 27s 696ms/step - loss: 0.4906 - accuracy: 0.8012 - top-5-accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.8602 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 17s 457ms/step - loss: 0.3555 - accuracy: 0.8641 - top-5-accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9292 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 17s 459ms/step - loss: 0.3001 - accuracy: 0.8898 - top-5-accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9320 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 17s 460ms/step - loss: 0.2367 - accuracy: 0.9110 - top-5-accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 17s 458ms/step - loss: 0.2117 - accuracy: 0.9251 - top-5-accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9622 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 18s 479ms/step - loss: 0.1762 - accuracy: 0.9380 - top-5-accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9717 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 21s 559ms/step - loss: 0.1763 - accuracy: 0.9405 - top-5-accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9830 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.1329 - accuracy: 0.9546 - top-5-accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.1620 - accuracy: 0.9456 - top-5-accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9773 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 16s 436ms/step - loss: 0.1152 - accuracy: 0.9595 - top-5-accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9830 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 17s 455ms/step - loss: 0.1155 - accuracy: 0.9579 - top-5-accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 13/250
# 38/38 [==============================] - 17s 458ms/step - loss: 0.1024 - accuracy: 0.9668 - top-5-accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch
250
# 38/38 [==============================] - 16s 418ms/step - loss: 0.0135 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 220/250
# 38/38 [==============================] - 16s 416ms/step - loss: 0.0093 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 221/250
# 38/38 [==============================] - 16s 415ms/step - loss: 0.0187 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 222/250
# 38/38 [==============================] - 16s 414ms/step - loss: 0.0421 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 223/250
# 38/38 [==============================] - 16s 415ms/step - loss: 0.0181 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 224/250
# 38/38 [==============================] - 16s 421ms/step - loss: 0.0189 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 225/250
# 38/38 [==============================] - 16s 415ms/step - loss: 0.0122 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 226/250
# 38/38 [==============================] - 16s 415ms/step - loss: 0.0096 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 227/250
# 38/38 [==============================] - 16s 417ms/step - loss: 0.0079 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 228/250
# 38/38 [==============================] - 16s 418ms/step - loss: 0.0111 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 229/250
# 38/38 [==============================] - 16s 419ms/step - loss: 0.0280 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 230/250
# 38/38 [==============================] - 16s 429ms/step - loss: 0.0154 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 231/250
# 38/38 [==============================] - 16s 420ms/step - loss: 0.0271 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 232/250
# 38/38 [==============================] - 16s 433ms/step - loss: 0.0165 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 233/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.0085 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 234/250
# 38/38 [==============================] - 16s 420ms/step - loss: 0.0168 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 235/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.0282 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 236/250
# 38/38 [==============================] - 16s 434ms/step - loss: 0.0178 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 237/250
# 38/38 [==============================] - 16s 434ms/step - loss: 0.0201 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 238/250
# 38/38 [==============================] - 16s 420ms/step - loss: 0.0262 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 239/250
# 38/38 [==============================] - 19s 506ms/step - loss: 0.0128 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 240/250
# 38/38 [==============================] - 16s 421ms/step - loss: 0.0064 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 241/250
# 38/38 [==============================] - 16s 419ms/step - loss: 0.0062 - accuracy: 0.9981 - top-5-accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 242/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.0041 - accuracy: 0.9988 - top-5-accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 243/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.0042 - accuracy: 0.9988 - top-5-accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 244/250
# 38/38 [==============================] - 16s 419ms/step - loss: 0.0029 - accuracy: 0.9994 - top-5-accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 245/250
# 38/38 [==============================] - 16s 434ms/step - loss: 0.0090 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 246/250
# 38/38 [==============================] - 16s 435ms/step - loss: 0.0040 - accuracy: 0.9990 - top-5-accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 247/250
# 38/38 [==============================] - 16s 419ms/step - loss: 0.0186 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 16s 420ms/step - loss: 0.0172 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 16s 433ms/step - loss: 0.0256 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 16s 436ms/step - loss: 0.0242 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 1s 30ms/step - loss: 4.8723e-04 - accuracy: 1.0000 - top-5-accuracy: 1.0000
# Test accuracy: 100.0%
# Test top 5 accuracy: 100.0%
# CPU times: user 1h 39min 51s, sys: 1min 21s, total: 1h 41min 12s
# Wall time: 1h 9min 32s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 415 ms, sys: 108 ms, total: 523 ms
# Wall time: 400 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 1s 28ms/step
# CPU times: user 1.89 s, sys: 131 ms, total: 2.02 s
# Wall time: 1.77 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 11 µs, sys: 0 ns, total: 11 µs
# Wall time: 15.5 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[305   0   0]
#  [  0 333   0]
#  [  0   0 421]]
# CPU times: user 310 ms, sys: 126 ms, total: 436 ms
# Wall time: 298 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       305
#          Downy Mildew       1.00      1.00      1.00       333
#             Leaf Spot       1.00      1.00      1.00       421
#
#              accuracy                           1.00      1059
#             macro avg       1.00      1.00      1.00      1059
#          weighted avg       1.00      1.00      1.00      1059
#
# CPU times: user 9.4 ms, sys: 990 µs, total: 10.4 ms
# Wall time: 10.8 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 1s 28ms/step
# CPU times: user 1.02 s, sys: 39 ms, total: 1.05 s
# Wall time: 744 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 10 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   0]
#  [  0 203   0]
#  [  0   0 251]]
# CPU times: user 282 ms, sys: 127 ms, total: 409 ms
# Wall time: 273 ms

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       200
#          Downy Mildew       1.00      1.00      1.00       203
#             Leaf Spot       1.00      1.00      1.00       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 7.94 ms, sys: 950 µs, total: 8.89 ms
# Wall time: 11.1 ms
