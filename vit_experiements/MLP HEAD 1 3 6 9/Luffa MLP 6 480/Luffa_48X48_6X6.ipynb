# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 10.2 ms, sys: 3.68 ms, total: 13.8 ms
# Wall time: 111 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# CPU times: user 1.48 s, sys: 248 ms, total: 1.73 s
# Wall time: 34.7 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# CPU times: user 137 ms, sys: 21.5 ms, total: 159 ms
# Wall time: 14.5 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# CPU times: user 116 ms, sys: 9.58 ms, total: 126 ms
# Wall time: 11.5 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 66 ms, sys: 39.6 ms, total: 106 ms
# Wall time: 544 ms

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 5.53 s, sys: 622 ms, total: 6.15 s
# Wall time: 8.69 s

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# CPU times: user 549 ms, sys: 58.2 ms, total: 607 ms
# Wall time: 1.2 s

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 11 µs, sys: 1 µs, total: 12 µs
# Wall time: 16.9 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 48
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.7 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")
# Out:
# CPU times: user 29.1 s, sys: 1.98 s, total: 31.1 s
# Wall time: 2min 52s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 27 µs, sys: 2 µs, total: 29 µs
# Wall time: 33.6 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6533
# CPU times: user 28.1 ms, sys: 2.84 ms, total: 30.9 ms
# Wall time: 170 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 13.3 ms, sys: 2.96 ms, total: 16.3 ms
# Wall time: 25.1 ms
#                    Filename       ClassId
# 0   Downey-Mildew (764).jpg  Downy Mildew
# 1   Downey-Mildew (257).jpg  Downy Mildew
# 2  Downey-Mildew (1269).jpg  Downy Mildew
# 3   Downey-Mildew (254).jpg  Downy Mildew
# 4  Downey-Mildew (1748).jpg  Downy Mildew

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 219 ms, sys: 19.8 ms, total: 239 ms
# Wall time: 349 ms

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 4.84 ms, sys: 69 µs, total: 4.91 ms
# Wall time: 5.31 ms
# Leaf Spot                2505
# Downy Mildew             2024
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 112 ms, sys: 1.83 ms, total: 114 ms
# Wall time: 127 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 30.6 ms, sys: 775 µs, total: 31.4 ms
# Wall time: 46 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 91.2 ms, sys: 199 ms, total: 290 ms
# Wall time: 299 ms

# %%
# %%time
print(X.shape)
# Out:
# (6533, 48, 48, 3)
# CPU times: user 788 µs, sys: 0 ns, total: 788 µs
# Wall time: 797 µs

# %%
# split with a stratified sampling
# %%time
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 68 ms, sys: 171 ms, total: 239 ms
# Wall time: 248 ms

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 62 ms, sys: 160 ms, total: 222 ms
# Wall time: 246 ms

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 48, 48, 3) - y_train shape: (4820,)
# x_val shape: (1059, 48, 48, 3) - y_val shape: (1059,)
# x_test shape: (654, 48, 48, 3) - y_test shape: (654,)
# CPU times: user 2.02 ms, sys: 0 ns, total: 2.02 ms
# Wall time: 4.62 ms

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 82.6 ms, sys: 11 ms, total: 93.6 ms
# Wall time: 7.65 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 27 µs, sys: 3 µs, total: 30 µs
# Wall time: 33.9 µs

# %%
# %%time
num_classes = 3
input_shape = (48, 48, 3)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.58 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 48  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 6
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 8 µs, sys: 0 ns, total: 8 µs
# Wall time: 12.2 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 1.19 s, sys: 290 ms, total: 1.48 s
# Wall time: 1.48 s

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 61 µs, sys: 7 µs, total: 68 µs
# Wall time: 73.4 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 48 X 48
# Patch size: 6 X 6
# Patches per image: 64
# Elements per patch: 108
# CPU times: user 1.73 s, sys: 45.8 ms, total: 1.78 s
# Wall time: 1.79 s

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 71 µs, sys: 0 ns, total: 71 µs
# Wall time: 77.7 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.4 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.5 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7c21fc450a60>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7c21fc450a60>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7c21fc450a60>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7c21fc450a60>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7c21f75da1a0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7c21f75da1a0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7c21f75da1a0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7c21f75da1a0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 48, 48, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patches_1 (Patches)         (None, None, 108)            0         ['data_augmentation[0][0]']
#
#  patch_encoder (PatchEncode  (None, 64, 64)               11072     ['patches_1[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 64, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 64, 64)               99520     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 64, 64)               0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 64, 64)               128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 64, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 64, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 64, 64)               8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64)               0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 64, 64)               0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 64, 64)               128       ['add_1[0][0]']
#  erNormalization)
#
#  flatten (Flatten)           (None, 4096)                 0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 4096)                 0         ['flatten[0][0]']
#
#  dense_3 (Dense)             (None, 2048)                 8390656   ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024)                 2098176   ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    3075      ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 10619466 (40.51 MB)
# Trainable params: 10619459 (40.51 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 68s 2s/step - loss: 1.4707 - accuracy: 0.6448 - top-5-accuracy: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.8102 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.4608 - accuracy: 0.8259 - top-5-accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9084 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.3111 - accuracy: 0.8863 - top-5-accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 40s 1s/step - loss: 0.2321 - accuracy: 0.9189 - top-5-accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9736 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 38s 995ms/step - loss: 0.1740 - accuracy: 0.9353 - top-5-accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9736 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 42s 1s/step - loss: 0.1085 - accuracy: 0.9608 - top-5-accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9849 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.1206 - accuracy: 0.9598 - top-5-accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.1040 - accuracy: 0.9610 - top-5-accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.0850 - accuracy: 0.9699 - top-5-accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9783 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 36s 947ms/step - loss: 0.0871 - accuracy: 0.9720 - top-5-accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0768 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 37s 982ms/step - loss: 0.0508 - accuracy: 0.9824 - top-5-accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 13/250
# 38/38 [==============================] - 36s 956ms/step - loss: 0.0536 - accuracy: 0.9793 - top-5-accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 14/250
# 38/38 [==============================] - 40s 1s/step - loss: 0.0585 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 15/250
# 38/38 [==============================] - 38s 993ms/step - loss: 0.0621 - accuracy: 0.9813 - top-5-accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 16/250
# 38/38 [==============================] - 37s 986ms/step - loss: 0.0473 - accuracy: 0.9840 - top-5-accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 17/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0774 - accuracy: 0.9720 - top-5-accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 18/250
# 38/38 [==============================] - 37s 972ms/step - loss: 0.0582 - accuracy: 0.9807 - top-5-accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9830 - val_top-5-accuracy: 1.0000
# Epoch 19/250
# 38/38 [==============================] - 37s 982ms/step - loss: 0.0467 - accuracy: 0.9828 - top-5-accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 20/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.0543 - accuracy: 0.9849 - top-5-accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 21/250
# 38/38 [==============================] - 37s 965ms/step - loss: 0.0226 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 22/250
# 38/38 [==============================] - 42s 1s/step - loss: 0.0296 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 23/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0291 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 24/250
# 38/38 [==============================] - 38s 997ms/step - loss: 0.0372 - accuracy: 0.9863 - top-5-accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 25/250
# 38/38 [==============================] - 39s 1s/step - loss: 0.0387 - accuracy: 0.9863 - top-5-accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 26/250
# 38/38 [==============================] - 36s 955ms/step - loss: 0.0377 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 27/250
# 38/38 [==============================] - 40s 1s/step - loss: 0.0542 - accuracy: 0.9822 - top-5-accuracy: 1.0000 - val_loss: 0.0530 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 28/250
# 38/38 [==============================] - 36s 955ms/step - loss: 0.0383 - accuracy: 0.9863 - top-5-accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 29/250
# 38/38 [==============================] - 38s 992ms/step - loss: 0.0417 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 30/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0304 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 31/250
# 38/38 [==============================] - 36s 947ms/step - loss: 0.0312 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 32/250
# 38/38 [==============================] - 36s 954ms/step - loss: 0.0357 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 33/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0243 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 34/250
# 38/38 [==============================] - 37s 956ms/step - loss: 0.0349 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 35/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0196 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 36/250
# 38/38 [==============================] - 38s 1s/step - loss: 0.0177 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 37/250
# 38/38 [==============================] - 38s 996ms/step - loss: 0.0131 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch
- accuracy: 0.9990 - top-5-accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 36s 963ms/step - loss: 0.0022 - accuracy: 0.9992 - top-5-accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 35s 926ms/step - loss: 0.0127 - accuracy: 0.9973 - top-5-accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 37s 969ms/step - loss: 0.0254 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 1s 62ms/step - loss: 7.2579e-05 - accuracy: 1.0000 - top-5-accuracy: 1.0000
# Test accuracy: 100.0%
# Test top 5 accuracy: 100.0%
# CPU times: user 3h 33min 44s, sys: 17min 4s, total: 3h 50min 48s
# Wall time: 2h 35min 31s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 868 ms, sys: 113 ms, total: 982 ms
# Wall time: 866 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 3s 92ms/step
# CPU times: user 3.51 s, sys: 71.4 ms, total: 3.59 s
# Wall time: 5.56 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 17 µs, sys: 1e+03 ns, total: 18 µs
# Wall time: 32.4 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[305   0   0]
#  [  0 333   0]
#  [  0   0 421]]
# CPU times: user 336 ms, sys: 134 ms, total: 469 ms
# Wall time: 327 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       305
#          Downy Mildew       1.00      1.00      1.00       333
#             Leaf Spot       1.00      1.00      1.00       421
#
#              accuracy                           1.00      1059
#             macro avg       1.00      1.00      1.00      1059
#          weighted avg       1.00      1.00      1.00      1059
#
# CPU times: user 13.4 ms, sys: 34 µs, total: 13.4 ms
# Wall time: 13.2 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 1s 57ms/step
# CPU times: user 2.01 s, sys: 59.9 ms, total: 2.07 s
# Wall time: 1.32 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 11 µs, sys: 0 ns, total: 11 µs
# Wall time: 16.7 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   0]
#  [  0 203   0]
#  [  0   0 251]]
# CPU times: user 309 ms, sys: 125 ms, total: 433 ms
# Wall time: 290 ms

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       200
#          Downy Mildew       1.00      1.00      1.00       203
#             Leaf Spot       1.00      1.00      1.00       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 11.7 ms, sys: 0 ns, total: 11.7 ms
# Wall time: 16.7 ms
