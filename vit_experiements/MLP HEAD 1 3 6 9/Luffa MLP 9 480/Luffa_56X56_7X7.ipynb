# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 8.14 ms, sys: 3.2 ms, total: 11.3 ms
# Wall time: 108 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# CPU times: user 1.2 s, sys: 178 ms, total: 1.38 s
# Wall time: 42.9 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# CPU times: user 76.8 ms, sys: 16.1 ms, total: 92.9 ms
# Wall time: 8.65 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# CPU times: user 88 ms, sys: 13.8 ms, total: 102 ms
# Wall time: 9.66 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 74.4 ms, sys: 32.9 ms, total: 107 ms
# Wall time: 780 ms

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 4.19 s, sys: 528 ms, total: 4.72 s
# Wall time: 5.63 s

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# CPU times: user 664 ms, sys: 50.4 ms, total: 715 ms
# Wall time: 926 ms

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 0 ns, sys: 14 µs, total: 14 µs
# Wall time: 18.6 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 56
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 7 µs, sys: 1e+03 ns, total: 8 µs
# Wall time: 12.2 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")
# Out:
# CPU times: user 29.7 s, sys: 2.21 s, total: 31.9 s
# Wall time: 3min 21s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 25 µs, sys: 2 µs, total: 27 µs
# Wall time: 30.3 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6533
# CPU times: user 24 ms, sys: 3.95 ms, total: 28 ms
# Wall time: 146 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 11.9 ms, sys: 0 ns, total: 11.9 ms
# Wall time: 22.8 ms
#                Filename    ClassId
# 0   Leaf-Spot (247).jpg  Leaf Spot
# 1  Leaf-Spot (1514).jpg  Leaf Spot
# 2   Leaf-Spot (886).jpg  Leaf Spot
# 3   Leaf-Spot (888).jpg  Leaf Spot
# 4   Leaf-Spot (248).jpg  Leaf Spot

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 192 ms, sys: 14.8 ms, total: 207 ms
# Wall time: 245 ms

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 3 ms, sys: 0 ns, total: 3 ms
# Wall time: 4.02 ms
# Leaf Spot                2505
# Downy Mildew             2024
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 105 ms, sys: 2.05 ms, total: 107 ms
# Wall time: 121 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 22.8 ms, sys: 999 µs, total: 23.8 ms
# Wall time: 25.3 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 111 ms, sys: 149 ms, total: 260 ms
# Wall time: 264 ms

# %%
# %%time
print(X.shape)
# Out:
# (6533, 56, 56, 3)
# CPU times: user 875 µs, sys: 0 ns, total: 875 µs
# Wall time: 883 µs

# %%
# %%time
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 62.4 ms, sys: 134 ms, total: 196 ms
# Wall time: 198 ms

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 52.3 ms, sys: 127 ms, total: 179 ms
# Wall time: 180 ms

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 56, 56, 3) - y_train shape: (4820,)
# x_val shape: (1059, 56, 56, 3) - y_val shape: (1059,)
# x_test shape: (654, 56, 56, 3) - y_test shape: (654,)
# CPU times: user 2.71 ms, sys: 0 ns, total: 2.71 ms
# Wall time: 3.23 ms

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 61.9 ms, sys: 9.21 ms, total: 71.1 ms
# Wall time: 6.34 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 25 µs, sys: 3 µs, total: 28 µs
# Wall time: 38.6 µs

# %%
# %%time
num_classes = 3
input_shape = (56, 56, 3)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.63 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 56  # We'll resize input images to this size
patch_size = 7  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 9
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 11 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 1.66 s, sys: 342 ms, total: 2 s
# Wall time: 2.3 s

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 0 ns, sys: 23 µs, total: 23 µs
# Wall time: 27.9 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 59 µs, sys: 0 ns, total: 59 µs
# Wall time: 63.9 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 56 X 56
# Patch size: 7 X 7
# Patches per image: 64
# Elements per patch: 147
# CPU times: user 2.19 s, sys: 59.1 ms, total: 2.25 s
# Wall time: 2.41 s

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 70 µs, sys: 0 ns, total: 70 µs
# Wall time: 74.6 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11.2 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 11.4 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x799f838beb90>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x799f838beb90>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x799f838beb90>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x799f838beb90>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x799f838bfb50>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x799f838bfb50>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x799f838bfb50>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x799f838bfb50>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 56, 56, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 56, 56, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patches_1 (Patches)         (None, None, 147)            0         ['data_augmentation[0][0]']
#
#  patch_encoder (PatchEncode  (None, 64, 64)               13568     ['patches_1[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 64, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 64, 64)               149248    ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 64, 64)               0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 64, 64)               128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 64, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 64, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 64, 64)               8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64)               0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 64, 64)               0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 64, 64)               128       ['add_1[0][0]']
#  erNormalization)
#
#  flatten (Flatten)           (None, 4096)                 0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 4096)                 0         ['flatten[0][0]']
#
#  dense_3 (Dense)             (None, 2048)                 8390656   ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024)                 2098176   ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    3075      ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 10671690 (40.71 MB)
# Trainable params: 10671683 (40.71 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 81s 2s/step - loss: 1.1959 - accuracy: 0.6797 - top-5-accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.7904 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 47s 1s/step - loss: 0.4743 - accuracy: 0.8220 - top-5-accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.8886 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 46s 1s/step - loss: 0.2990 - accuracy: 0.8915 - top-5-accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9358 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 54s 1s/step - loss: 0.1924 - accuracy: 0.9280 - top-5-accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9566 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.1560 - accuracy: 0.9432 - top-5-accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 0.9613 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0949 - accuracy: 0.9676 - top-5-accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9707 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0954 - accuracy: 0.9660 - top-5-accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9660 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.0988 - accuracy: 0.9635 - top-5-accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 0.9821 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 55s 1s/step - loss: 0.0941 - accuracy: 0.9668 - top-5-accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9773 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 59s 2s/step - loss: 0.0756 - accuracy: 0.9743 - top-5-accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 52s 1s/step - loss: 0.0834 - accuracy: 0.9705 - top-5-accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9745 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0755 - accuracy: 0.9747 - top-5-accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 13/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.
uracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 229/250
# 38/38 [==============================] - 50s 1s/step - loss: 3.4317e-04 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 230/250
# 38/38 [==============================] - 49s 1s/step - loss: 2.9837e-04 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 231/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.0035 - accuracy: 0.9992 - top-5-accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 232/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.0223 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 233/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.0228 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 234/250
# 38/38 [==============================] - 48s 1s/step - loss: 0.0113 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 235/250
# 38/38 [==============================] - 54s 1s/step - loss: 0.0217 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 236/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.0124 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 237/250
# 38/38 [==============================] - 53s 1s/step - loss: 0.0119 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 238/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0067 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 239/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.0079 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 240/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.0104 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 241/250
# 38/38 [==============================] - 53s 1s/step - loss: 0.0116 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 242/250
# 38/38 [==============================] - 48s 1s/step - loss: 0.0145 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 243/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0082 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 244/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.0128 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 245/250
# 38/38 [==============================] - 49s 1s/step - loss: 0.0092 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 246/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0081 - accuracy: 0.9977 - top-5-accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 247/250
# 38/38 [==============================] - 52s 1s/step - loss: 0.0190 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 50s 1s/step - loss: 0.0458 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 51s 1s/step - loss: 0.0279 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 48s 1s/step - loss: 0.0096 - accuracy: 0.9973 - top-5-accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 3s 125ms/step - loss: 0.0088 - accuracy: 0.9969 - top-5-accuracy: 1.0000
# Test accuracy: 99.69%
# Test top 5 accuracy: 100.0%
# CPU times: user 4h 48min 58s, sys: 25min 42s, total: 5h 14min 40s
# Wall time: 3h 34min 35s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 448 ms, sys: 108 ms, total: 556 ms
# Wall time: 440 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 3s 81ms/step
# CPU times: user 5.17 s, sys: 229 ms, total: 5.4 s
# Wall time: 5.94 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 40 µs, sys: 0 ns, total: 40 µs
# Wall time: 46.7 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[305   0   0]
#  [  0 333   0]
#  [  0   1 420]]
# CPU times: user 335 ms, sys: 131 ms, total: 466 ms
# Wall time: 328 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       305
#          Downy Mildew       1.00      1.00      1.00       333
#             Leaf Spot       1.00      1.00      1.00       421
#
#              accuracy                           1.00      1059
#             macro avg       1.00      1.00      1.00      1059
#          weighted avg       1.00      1.00      1.00      1059
#
# CPU times: user 13.7 ms, sys: 0 ns, total: 13.7 ms
# Wall time: 15.4 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 2s 84ms/step
# CPU times: user 2.55 s, sys: 83.3 ms, total: 2.64 s
# Wall time: 2.68 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 13 µs, sys: 0 ns, total: 13 µs
# Wall time: 18.6 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   0]
#  [  0 202   1]
#  [  0   1 250]]
# CPU times: user 1.8 s, sys: 126 ms, total: 1.93 s
# Wall time: 1.97 s

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       200
#          Downy Mildew       1.00      1.00      1.00       203
#             Leaf Spot       1.00      1.00      1.00       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 9.74 ms, sys: 0 ns, total: 9.74 ms
# Wall time: 9.85 ms
