# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 5.77 ms, sys: 2.22 ms, total: 8 ms
# Wall time: 129 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# CPU times: user 1.74 s, sys: 345 ms, total: 2.09 s
# Wall time: 27.8 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# CPU times: user 53.8 ms, sys: 6.89 ms, total: 60.7 ms
# Wall time: 5.93 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18)
# CPU times: user 64.2 ms, sys: 14.1 ms, total: 78.3 ms
# Wall time: 8.36 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 14 µs, sys: 2 µs, total: 16 µs
# Wall time: 21.7 µs

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 67 µs, sys: 0 ns, total: 67 µs
# Wall time: 346 µs

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# CPU times: user 1.1 ms, sys: 0 ns, total: 1.1 ms
# Wall time: 1.19 ms

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 11 µs, sys: 2 µs, total: 13 µs
# Wall time: 17.2 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 28
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.34 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 480")
# Out:
# CPU times: user 31.4 s, sys: 2.15 s, total: 33.6 s
# Wall time: 3min 39s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 27 µs, sys: 0 ns, total: 27 µs
# Wall time: 31.2 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6533
# CPU times: user 29.3 ms, sys: 0 ns, total: 29.3 ms
# Wall time: 212 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 12 ms, sys: 544 µs, total: 12.5 ms
# Wall time: 13.6 ms
#                    Filename       ClassId
# 0  Downey-Mildew (1754).jpg  Downy Mildew
# 1   Downey-Mildew (257).jpg  Downy Mildew
# 2  Downey-Mildew (1751).jpg  Downy Mildew
# 3  Downey-Mildew (1747).jpg  Downy Mildew
# 4  Downey-Mildew (1265).jpg  Downy Mildew

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 480',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 195 ms, sys: 8.59 ms, total: 203 ms
# Wall time: 230 ms

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 3.36 ms, sys: 951 µs, total: 4.31 ms
# Wall time: 4.46 ms
# Leaf Spot                2505
# Downy Mildew             2024
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 114 ms, sys: 1.81 ms, total: 116 ms
# Wall time: 134 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 20.9 ms, sys: 0 ns, total: 20.9 ms
# Wall time: 22.2 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 50.3 ms, sys: 46.4 ms, total: 96.7 ms
# Wall time: 107 ms

# %%
# %%time
print(X.shape)
# Out:
# (6533, 28, 28, 3)
# CPU times: user 889 µs, sys: 0 ns, total: 889 µs
# Wall time: 900 µs

# %%
# %%time
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 19.8 ms, sys: 38.3 ms, total: 58.1 ms
# Wall time: 59 ms

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 12.7 ms, sys: 40.3 ms, total: 52.9 ms
# Wall time: 53.6 ms

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 28, 28, 3) - y_train shape: (4820,)
# x_val shape: (1059, 28, 28, 3) - y_val shape: (1059,)
# x_test shape: (654, 28, 28, 3) - y_test shape: (654,)
# CPU times: user 2.01 ms, sys: 0 ns, total: 2.01 ms
# Wall time: 2.94 ms

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 62.2 ms, sys: 9.43 ms, total: 71.6 ms
# Wall time: 6.75 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 23 µs, sys: 0 ns, total: 23 µs
# Wall time: 26.7 µs

# %%
# %%time
num_classes = 3
input_shape = (28, 28, 3)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.44 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 28  # We'll resize input images to this size
patch_size = 7  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 9
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 10 µs, sys: 1 µs, total: 11 µs
# Wall time: 15.3 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 1.1 s, sys: 88.5 ms, total: 1.19 s
# Wall time: 1.22 s

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10.5 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 56 µs, sys: 0 ns, total: 56 µs
# Wall time: 61 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 28 X 28
# Patch size: 7 X 7
# Patches per image: 16
# Elements per patch: 147
# CPU times: user 524 ms, sys: 1.92 ms, total: 526 ms
# Wall time: 659 ms

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 109 µs, sys: 10 µs, total: 119 µs
# Wall time: 64.1 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 10 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 8 µs, sys: 0 ns, total: 8 µs
# Wall time: 12.9 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7af738b34d00>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7af738b34d00>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7af738b34d00>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7af738b34d00>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7af73ae75c90>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7af73ae75c90>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7af73ae75c90>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7af73ae75c90>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 28, 28, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patches_2 (Patches)         (None, None, 147)            0         ['data_augmentation[0][0]']
#
#  patch_encoder_1 (PatchEnco  (None, 16, 64)               10496     ['patches_2[0][0]']
#  der)
#
#  layer_normalization_3 (Lay  (None, 16, 64)               128       ['patch_encoder_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 16, 64)               149248    ['layer_normalization_3[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_3[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 16, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'patch_encoder_1[0][0]']
#
#  layer_normalization_4 (Lay  (None, 16, 64)               128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 16, 128)              8320      ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 16, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 16, 64)               8256      ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)         (None, 16, 64)               0         ['dense_8[0][0]']
#
#  add_3 (Add)                 (None, 16, 64)               0         ['dropout_6[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_5 (Lay  (None, 16, 64)               128       ['add_3[0][0]']
#  erNormalization)
#
#  flatten_1 (Flatten)         (None, 1024)                 0         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 1024)                 0         ['flatten_1[0][0]']
#
#  dense_9 (Dense)             (None, 2048)                 2099200   ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)         (None, 2048)                 0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024)                 2098176   ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024)                 0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 3)                    3075      ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 4377162 (16.70 MB)
# Trainable params: 4377155 (16.70 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 26s 577ms/step - loss: 0.9844 - accuracy: 0.6490 - top-5-accuracy: 1.0000 - val_loss: 0.5225 - val_accuracy: 0.7866 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 23s 613ms/step - loss: 0.5103 - accuracy: 0.7954 - top-5-accuracy: 1.0000 - val_loss: 0.3377 - val_accuracy: 0.8697 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 16s 410ms/step - loss: 0.3946 - accuracy: 0.8492 - top-5-accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9160 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 11s 284ms/step - loss: 0.3096 - accuracy: 0.8834 - top-5-accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9330 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 13s 345ms/step - loss: 0.2502 - accuracy: 0.9035 - top-5-accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9556 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 14s 373ms/step - loss: 0.2143 - accuracy: 0.9237 - top-5-accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9660 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 13s 342ms/step - loss: 0.1784 - accuracy: 0.9340 - top-5-accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 14s 377ms/step - loss: 0.1642 - accuracy: 0.9421 - top-5-accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9651 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 12s 321ms/step - loss: 0.1354 - accuracy: 0.9521 - top-5-accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 14s 373ms/step - loss: 0.1264 - accuracy: 0.9539 - top-5-accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9745 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 11s 294ms/step - loss: 0.1092 - accuracy: 0.9620 - top-5-accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 11s 289ms/step - loss: 0.1047 - accuracy: 0.9647 - top-5-accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9792 - val_top-5-accuracy: 1.0000
# Epoch 13/250
# 38/38 [==============================] - 12s 323ms/step - loss: 0.1085 - accuracy: 0.9637 - top-5-accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9802 - val_top-5-accuracy: 1.0000
# Epoch 14/250
# 38/38 [==============================] - 12s 318ms/step - loss: 0.0832 - accuracy: 0.9693 - top-5-accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 15/250
# 38/38 [==============================] - 11s 283ms/step - loss: 0.0680 - accuracy: 0.9778 - top-5-accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 16/250
# 38/38 [==============================] - 12s 314ms/step - loss: 0.0754 - accuracy: 0.9745 - top-5-accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 17/250
# 38/38 [==============================] - 12s 326ms/step - loss: 0.0679 - accuracy: 0.9766 - top-5-accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 18/250
# 38/38 [==============================] - 12s 325ms/step - loss: 0.0873 - accuracy: 0.9730 - top-5-accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 19/250
# 38/38 [==============================] - 13s 340ms/step - loss: 0.0759 - accuracy: 0.9734 - top-5-accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 20/250
# 38/38 [==============================] - 11s 291ms/step - loss: 0.0738 - accuracy: 0.9741 - top-5-accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9858 - val_top-5-accuracy: 1.0000
# Epoch 21/250
# 38/38 [==============================] - 12s 322ms/step - loss: 0.0616 - accuracy: 0.9788 - top-5-accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 22/250
# 38/38 [==============================] - 13s 332ms/step - loss: 0.0491 - accuracy: 0.9817 - top-5-accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 23/250
# 38/38 [==============================] - 10s 260ms/step - loss: 0.0621 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 24/250
# 38/38 [==============================] - 12s 319ms/step - loss: 0.0554 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 25/250
# 38/38 [==============================] - 12s 322ms/step - loss: 0.0499 - accuracy: 0.9846 - top-5-accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 26/250
# 38/38 [==============================] - 11s 283ms/step - loss: 0.0427 - accuracy: 0.9822 - top-5-accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 27/250
# 38/38 [==============================] - 11s 293ms/step - loss: 0.0467 - accuracy: 0.9822 - top-5-accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 28/250
# 38/38 [==============================] - 12s 321ms/step - loss: 0.0524 - accuracy: 0.9824 - top-5-accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 29/250
# 38/38 [==============================] - 11s 304ms/step - loss: 0.0560 - accuracy: 0.9824 - top-5-accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 30/250
# 38/38 [==============================] - 10s 268ms/step - loss: 0.0406 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 31/250
# 38/38 [==============================] - 12s 321ms/step - loss: 0.0308 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 32/250
# 38/38 [==============================] - 13s 333ms/step - loss: 0.0512 - accuracy: 0.9832 - top-5-accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 33/250
# 38/38 [==============================] - 11s 278ms/step - loss: 0.0625 - accuracy: 0.9782 - top-5-accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 34/250
# 38/38 [==============================] - 11s 299ms/step - loss: 0.0569 - accuracy: 0.9805 - top-5-accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 35/250
# 38/38 [==============================] - 12s 321ms/step - loss: 0.0482 - accuracy: 0.9840 - top-5-accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch
250
# 38/38 [==============================] - 12s 323ms/step - loss: 0.0139 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 233/250
# 38/38 [==============================] - 10s 266ms/step - loss: 0.0174 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 234/250
# 38/38 [==============================] - 12s 320ms/step - loss: 0.0127 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 235/250
# 38/38 [==============================] - 12s 327ms/step - loss: 0.0094 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 236/250
# 38/38 [==============================] - 11s 294ms/step - loss: 0.0073 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 237/250
# 38/38 [==============================] - 11s 291ms/step - loss: 0.0126 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 238/250
# 38/38 [==============================] - 12s 327ms/step - loss: 0.0197 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 239/250
# 38/38 [==============================] - 12s 323ms/step - loss: 0.0201 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 240/250
# 38/38 [==============================] - 10s 267ms/step - loss: 0.0261 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 241/250
# 38/38 [==============================] - 12s 328ms/step - loss: 0.0113 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 242/250
# 38/38 [==============================] - 15s 398ms/step - loss: 0.0131 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 243/250
# 38/38 [==============================] - 10s 263ms/step - loss: 0.0135 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 244/250
# 38/38 [==============================] - 13s 330ms/step - loss: 0.0141 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 245/250
# 38/38 [==============================] - 12s 330ms/step - loss: 0.0183 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 246/250
# 38/38 [==============================] - 11s 293ms/step - loss: 0.0115 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 247/250
# 38/38 [==============================] - 11s 298ms/step - loss: 0.0156 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 12s 325ms/step - loss: 0.0150 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 0.9991 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 12s 326ms/step - loss: 0.0203 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 10s 266ms/step - loss: 0.0164 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9981 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0058 - accuracy: 0.9969 - top-5-accuracy: 1.0000
# Test accuracy: 99.69%
# Test top 5 accuracy: 100.0%
# CPU times: user 1h 11min 1s, sys: 1min 12s, total: 1h 12min 14s
# Wall time: 49min 30s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 437 ms, sys: 111 ms, total: 547 ms
# Wall time: 457 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 1s 23ms/step
# CPU times: user 1.73 s, sys: 33.3 ms, total: 1.76 s
# Wall time: 1.32 s

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 16 µs, sys: 0 ns, total: 16 µs
# Wall time: 19.6 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[305   0   0]
#  [  0 333   0]
#  [  0   0 421]]
# CPU times: user 339 ms, sys: 130 ms, total: 468 ms
# Wall time: 324 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       305
#          Downy Mildew       1.00      1.00      1.00       333
#             Leaf Spot       1.00      1.00      1.00       421
#
#              accuracy                           1.00      1059
#             macro avg       1.00      1.00      1.00      1059
#          weighted avg       1.00      1.00      1.00      1059
#
# CPU times: user 10.6 ms, sys: 10 µs, total: 10.6 ms
# Wall time: 13.1 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 1s 23ms/step
# CPU times: user 848 ms, sys: 19.2 ms, total: 867 ms
# Wall time: 703 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 9 µs, sys: 0 ns, total: 9 µs
# Wall time: 13.4 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   0]
#  [  1 202   0]
#  [  1   0 250]]
# CPU times: user 305 ms, sys: 123 ms, total: 428 ms
# Wall time: 291 ms

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       0.99      1.00      1.00       200
#          Downy Mildew       1.00      1.00      1.00       203
#             Leaf Spot       1.00      1.00      1.00       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 11.1 ms, sys: 0 ns, total: 11.1 ms
# Wall time: 12.5 ms
