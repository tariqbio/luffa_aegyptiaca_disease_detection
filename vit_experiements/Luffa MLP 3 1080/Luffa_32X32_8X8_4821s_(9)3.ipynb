# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 2.91 ms, sys: 2.09 ms, total: 5 ms
# Wall time: 104 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# CPU times: user 525 ms, sys: 81.1 ms, total: 606 ms
# Wall time: 20.4 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3
# CPU times: user 25.7 ms, sys: 12.5 ms, total: 38.2 ms
# Wall time: 6.02 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 23.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# CPU times: user 25.6 ms, sys: 5.57 ms, total: 31.2 ms
# Wall time: 4.52 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 25.2 ms, sys: 19.3 ms, total: 44.5 ms
# Wall time: 304 ms

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 2.61 s, sys: 378 ms, total: 2.99 s
# Wall time: 3.35 s

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# CPU times: user 369 ms, sys: 18.9 ms, total: 388 ms
# Wall time: 510 ms

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 10.5 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 32
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.05 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca 1080")
# Out:
# CPU times: user 3min 8s, sys: 6.9 s, total: 3min 15s
# Wall time: 8min 14s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 49 µs, sys: 1 µs, total: 50 µs
# Wall time: 53.4 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 1080', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6533
# CPU times: user 16.1 ms, sys: 3.12 ms, total: 19.2 ms
# Wall time: 100 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 9.58 ms, sys: 1.04 ms, total: 10.6 ms
# Wall time: 17.4 ms
#                Filename    ClassId
# 0   Leaf-Spot (886).jpg  Leaf Spot
# 1   Leaf-Spot (894).jpg  Leaf Spot
# 2  Leaf-Spot (1505).jpg  Leaf Spot
# 3   Leaf-Spot (888).jpg  Leaf Spot
# 4   Leaf-Spot (889).jpg  Leaf Spot

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca 1080',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 231 ms, sys: 38.8 ms, total: 269 ms
# Wall time: 324 ms

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 2.59 ms, sys: 0 ns, total: 2.59 ms
# Wall time: 2.69 ms
# Leaf Spot                2505
# Downy Mildew             2024
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 71.2 ms, sys: 936 µs, total: 72.2 ms
# Wall time: 79.9 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 15.1 ms, sys: 8 µs, total: 15.2 ms
# Wall time: 14.6 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 21 ms, sys: 15.9 ms, total: 37 ms
# Wall time: 38.4 ms

# %%
# %%time
print(X.shape)
# Out:
# (6533, 32, 32, 3)
# CPU times: user 628 µs, sys: 0 ns, total: 628 µs
# Wall time: 2.92 ms

# %%
# %%time
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 17 ms, sys: 15.9 ms, total: 33 ms
# Wall time: 33.1 ms

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 5.13 ms, sys: 69.8 ms, total: 74.9 ms
# Wall time: 79.3 ms

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4820, 32, 32, 3) - y_train shape: (4820,)
# x_val shape: (1059, 32, 32, 3) - y_val shape: (1059,)
# x_test shape: (654, 32, 32, 3) - y_test shape: (654,)
# CPU times: user 804 µs, sys: 0 ns, total: 804 µs
# Wall time: 808 µs

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 38.3 ms, sys: 1.99 ms, total: 40.3 ms
# Wall time: 4.13 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 37 µs, sys: 1e+03 ns, total: 38 µs
# Wall time: 41.7 µs

# %%
# %%time
num_classes = 3
input_shape = (32, 32, 3)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.44 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 32  # We'll resize input images to this size
patch_size = 8  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 3
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.39 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 557 ms, sys: 53.2 ms, total: 610 ms
# Wall time: 598 ms

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 8.82 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 25 µs, sys: 1 µs, total: 26 µs
# Wall time: 27.7 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 32 X 32
# Patch size: 8 X 8
# Patches per image: 16
# Elements per patch: 192
# CPU times: user 221 ms, sys: 13.1 ms, total: 235 ms
# Wall time: 242 ms

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 72 µs, sys: 3 µs, total: 75 µs
# Wall time: 40.8 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 5.96 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 7.15 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7ed081e75ff0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7ed081e75ff0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7ed081e75ff0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7ed081e75ff0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7ed081e750c0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7ed081e750c0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7ed081e750c0>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7ed081e750c0>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 32, 32, 3)            7         ['input_1[0][0]']
#  ial)
#
#  patches_1 (Patches)         (None, None, 192)            0         ['data_augmentation[0][0]']
#
#  patch_encoder (PatchEncode  (None, 16, 64)               13376     ['patches_1[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 16, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 16, 64)               49792     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 16, 64)               0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 16, 64)               128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 16, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 16, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 16, 64)               8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 16, 64)               0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 16, 64)               0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 16, 64)               128       ['add_1[0][0]']
#  erNormalization)
#
#  flatten (Flatten)           (None, 1024)                 0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['flatten[0][0]']
#
#  dense_3 (Dense)             (None, 2048)                 2099200   ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 1024)                 2098176   ['dropout_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 1024)                 0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    3075      ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 4280586 (16.33 MB)
# Trainable params: 4280579 (16.33 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 13s 256ms/step - loss: 1.0685 - accuracy: 0.6446 - top-5-accuracy: 1.0000 - val_loss: 0.5354 - val_accuracy: 0.7696 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 11s 289ms/step - loss: 0.4921 - accuracy: 0.8050 - top-5-accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.8470 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 10s 259ms/step - loss: 0.3637 - accuracy: 0.8573 - top-5-accuracy: 1.0000 - val_loss: 0.2495 - val_accuracy: 0.9065 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 6s 160ms/step - loss: 0.3180 - accuracy: 0.8797 - top-5-accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9254 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.2328 - accuracy: 0.9133 - top-5-accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9585 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 6s 163ms/step - loss: 0.2123 - accuracy: 0.9234 - top-5-accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9575 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.1811 - accuracy: 0.9295 - top-5-accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9594 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 6s 167ms/step - loss: 0.1467 - accuracy: 0.9490 - top-5-accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9594 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 6s 154ms/step - loss: 0.1280 - accuracy: 0.9562 - top-5-accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.1488 - accuracy: 0.9494 - top-5-accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 7s 186ms/step - loss: 0.1306 - accuracy: 0.9575 - top-5-accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9754 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.1016 - accuracy: 0.9633 - top-5-accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 13/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0960 - accuracy: 0.9656 - top-5-accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 14/250
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0832 - accuracy: 0.9732 - top-5-accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 0.9802 - val_top-5-accuracy: 1.0000
# Epoch 15/250
# 38/38 [==============================] - 6s 160ms/step - loss: 0.0710 - accuracy: 0.9737 - top-5-accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 16/250
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0763 - accuracy: 0.9718 - top-5-accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 17/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0839 - accuracy: 0.9701 - top-5-accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9802 - val_top-5-accuracy: 1.0000
# Epoch 18/250
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0851 - accuracy: 0.9676 - top-5-accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9802 - val_top-5-accuracy: 1.0000
# Epoch 19/250
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0834 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 20/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0693 - accuracy: 0.9768 - top-5-accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 21/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0511 - accuracy: 0.9815 - top-5-accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 22/250
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0750 - accuracy: 0.9739 - top-5-accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9858 - val_top-5-accuracy: 1.0000
# Epoch 23/250
# 38/38 [==============================] - 7s 189ms/step - loss: 0.0637 - accuracy: 0.9780 - top-5-accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 24/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0633 - accuracy: 0.9786 - top-5-accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9849 - val_top-5-accuracy: 1.0000
# Epoch 25/250
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0748 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 26/250
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0593 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 27/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0520 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 28/250
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0494 - accuracy: 0.9840 - top-5-accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9858 - val_top-5-accuracy: 1.0000
# Epoch 29/250
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0618 - accuracy: 0.9780 - top-5-accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9811 - val_top-5-accuracy: 1.0000
# Epoch 30/250
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0440 - accuracy: 0.9834 - top-5-accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 31/250
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0461 - accuracy: 0.9855 - top-5-accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 32/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0563 - accuracy: 0.9797 - top-5-accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 33/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0370 - accuracy: 0.9873 - top-5-accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9764 - val_top-5-accuracy: 1.0000
# Epoch 34/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0515 - accuracy: 0.9842 - top-5-accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 35/250
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0509 - accuracy: 0.9815 - top-5-accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 36/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0360 - accuracy: 0.9867 - top-5-accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 37/250
# 38/38 [==============================] - 7s 182ms/step - loss: 0.0373 - accuracy: 0.9876 - top-5-accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 38/250
# 38/38 [==============================] - 6s 159ms/step - loss: 0.0473 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9858 - val_top-5-accuracy: 1.0000
# Epoch 39/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0472 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9821 - val_top-5-accuracy: 1.0000
# Epoch 40/250
# 38/38 [==============================] - 6s 172ms/step - loss: 0.0433 - accuracy: 0.9867 - top-5-accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 41/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0318 - accuracy: 0.9880 - top-5-accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 42/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0323 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 43/250
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0300 - accuracy: 0.9876 - top-5-accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 44/250
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0307 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 45/250
# 38/38 [==============================] - 6s 154ms/step - loss: 0.0293 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 46/250
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0384 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 47/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0395 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 48/250
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0361 - accuracy: 0.9865 - top-5-accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 49/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0283 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 50/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0338 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 51/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0444 - accuracy: 0.9836 - top-5-accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 52/250
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0397 - accuracy: 0.9855 - top-5-accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 53/250
# 38/38 [==============================] - 7s 179ms/step - loss: 0.0318 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 54/250
# 38/38 [==============================] - 6s 155ms/step - loss: 0.0246 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 55/250
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0340 - accuracy: 0.9886 - top-5-accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 56/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0339 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 57/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0445 - accuracy: 0.9853 - top-5-accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 58/250
# 38/38 [==============================] - 7s 180ms/step - loss: 0.0428 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 59/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0371 - accuracy: 0.9846 - top-5-accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 60/250
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0419 - accuracy: 0.9865 - top-5-accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 61/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0370 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9858 - val_top-5-accuracy: 1.0000
# Epoch 62/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0347 - accuracy: 0.9880 - top-5-accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 63/250
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0241 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 64/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0275 - accuracy: 0.9902 - top-5-accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 65/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0345 - accuracy: 0.9880 - top-5-accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 66/250
# 38/38 [==============================] - 6s 172ms/step - loss: 0.0259 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 67/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0256 - accuracy: 0.9907 - top-5-accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 68/250
# 38/38 [==============================] - 6s 159ms/step - loss: 0.0279 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 69/250
# 38/38 [==============================] - 7s 191ms/step - loss: 0.0202 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 70/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0413 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 71/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0298 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 72/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0364 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 73/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0226 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 74/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0180 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 75/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0223 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 76/250
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0301 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 77/250
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0232 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 78/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0270 - accuracy: 0.9907 - top-5-accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 79/250
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0177 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 80/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0282 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 81/250
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0282 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 82/250
# 38/38 [==============================] - 6s 163ms/step - loss: 0.0245 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 83/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0199 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 84/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0154 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 85/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0202 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 86/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0250 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 87/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0225 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 88/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0282 - accuracy: 0.9907 - top-5-accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 89/250
# 38/38 [==============================] - 6s 156ms/step - loss: 0.0190 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 90/250
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0360 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 91/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0317 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 92/250
# 38/38 [==============================] - 6s 172ms/step - loss: 0.0250 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 93/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0245 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 94/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0316 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 95/250
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0237 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 96/250
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0246 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 97/250
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0252 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 98/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0176 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 99/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0241 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 100/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0270 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 101/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0285 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 102/250
# 38/38 [==============================] - 6s 166ms/step - loss: 0.0304 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 103/250
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0290 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 104/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0273 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 105/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0219 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 106/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0321 - accuracy: 0.9884 - top-5-accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 107/250
# 38/38 [==============================] - 6s 156ms/step - loss: 0.0307 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 108/250
# 38/38 [==============================] - 6s 155ms/step - loss: 0.0446 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 109/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0286 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 110/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0426 - accuracy: 0.9873 - top-5-accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 111/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0214 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 112/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0205 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 113/250
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0238 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 114/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0159 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 115/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0141 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 116/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0120 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 117/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0180 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 118/250
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0290 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 119/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0162 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 120/250
# 38/38 [==============================] - 6s 165ms/step - loss: 0.0119 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 121/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0226 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 122/250
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0314 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 123/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0183 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 124/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0169 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 125/250
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0229 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 126/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0359 - accuracy: 0.9880 - top-5-accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 127/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0188 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 128/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0170 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 129/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0117 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 130/250
# 38/38 [==============================] - 6s 166ms/step - loss: 0.0174 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 131/250
# 38/38 [==============================] - 6s 165ms/step - loss: 0.0168 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 132/250
# 38/38 [==============================] - 7s 191ms/step - loss: 0.0211 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 133/250
# 38/38 [==============================] - 6s 155ms/step - loss: 0.0201 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 134/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0149 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 135/250
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0234 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 136/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0144 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 137/250
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0155 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 138/250
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0259 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0468 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 139/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0266 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 140/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0139 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 141/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0248 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 142/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0159 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 143/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0098 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 144/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0173 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 145/250
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0175 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 146/250
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0269 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 147/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0213 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 148/250
# 38/38 [==============================] - 7s 197ms/step - loss: 0.0176 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 149/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0112 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 150/250
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0295 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 151/250
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0278 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 152/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0169 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 153/250
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0131 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 154/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0298 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 155/250
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0234 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 156/250
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0239 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 157/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0163 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 158/250
# 38/38 [==============================] - 7s 175ms/step - loss: 0.0151 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 159/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0191 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 160/250
# 38/38 [==============================] - 5s 145ms/step - loss: 0.0231 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 161/250
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0161 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 162/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0233 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 163/250
# 38/38 [==============================] - 7s 194ms/step - loss: 0.0188 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 164/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0143 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 165/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0101 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 166/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0171 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 167/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0180 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 168/250
# 38/38 [==============================] - 7s 183ms/step - loss: 0.0197 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 169/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0293 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 170/250
# 38/38 [==============================] - 6s 154ms/step - loss: 0.0149 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 171/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0215 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 172/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0272 - accuracy: 0.9917 - top-5-accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 173/250
# 38/38 [==============================] - 7s 195ms/step - loss: 0.0158 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 174/250
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0309 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 175/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0140 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 176/250
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0137 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 177/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0199 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 178/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0165 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0547 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 179/250
# 38/38 [==============================] - 6s 166ms/step - loss: 0.0248 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 180/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0248 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 181/250
# 38/38 [==============================] - 7s 177ms/step - loss: 0.0196 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 182/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0218 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9896 - val_top-5-accuracy: 1.0000
# Epoch 183/250
# 38/38 [==============================] - 6s 149ms/step - loss: 0.0182 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 184/250
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0096 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 185/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0166 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 186/250
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0218 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 187/250
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0188 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 188/250
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0127 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 189/250
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0244 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 190/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0359 - accuracy: 0.9884 - top-5-accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 191/250
# 38/38 [==============================] - 6s 170ms/step - loss: 0.0135 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 192/250
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0087 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 193/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0079 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 194/250
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0069 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 195/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0088 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 196/250
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0135 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 197/250
# 38/38 [==============================] - 6s 148ms/step - loss: 0.0183 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 198/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0175 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 199/250
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0118 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 200/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0157 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 201/250
# 38/38 [==============================] - 6s 155ms/step - loss: 0.0132 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 202/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0162 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9868 - val_top-5-accuracy: 1.0000
# Epoch 203/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0246 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9877 - val_top-5-accuracy: 1.0000
# Epoch 204/250
# 38/38 [==============================] - 7s 178ms/step - loss: 0.0250 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 205/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0242 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 206/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0270 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 207/250
# 38/38 [==============================] - 6s 163ms/step - loss: 0.0146 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 208/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0175 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 209/250
# 38/38 [==============================] - 6s 172ms/step - loss: 0.0189 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 210/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0143 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 211/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0168 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 212/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0149 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 213/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0119 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 214/250
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0114 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 215/250
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0100 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 216/250
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0332 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 217/250
# 38/38 [==============================] - 7s 174ms/step - loss: 0.0270 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 218/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0134 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 219/250
# 38/38 [==============================] - 6s 156ms/step - loss: 0.0193 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 220/250
# 38/38 [==============================] - 6s 160ms/step - loss: 0.0152 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 221/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0180 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 222/250
# 38/38 [==============================] - 7s 180ms/step - loss: 0.0165 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 223/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0223 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 224/250
# 38/38 [==============================] - 7s 196ms/step - loss: 0.0243 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 225/250
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0183 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 226/250
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0076 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 227/250
# 38/38 [==============================] - 7s 181ms/step - loss: 0.0111 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 228/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0117 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 229/250
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0144 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 230/250
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0207 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 231/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0117 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 232/250
# 38/38 [==============================] - 6s 171ms/step - loss: 0.0207 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 233/250
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0153 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 234/250
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0098 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 235/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0109 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 236/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0155 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 237/250
# 38/38 [==============================] - 6s 158ms/step - loss: 0.0144 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 238/250
# 38/38 [==============================] - 6s 152ms/step - loss: 0.0201 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9906 - val_top-5-accuracy: 1.0000
# Epoch 239/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0171 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 240/250
# 38/38 [==============================] - 7s 172ms/step - loss: 0.0116 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 241/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0147 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 242/250
# 38/38 [==============================] - 6s 154ms/step - loss: 0.0106 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 243/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0134 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 244/250
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0208 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 245/250
# 38/38 [==============================] - 7s 177ms/step - loss: 0.0219 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 246/250
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0216 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 247/250
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0128 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 6s 169ms/step - loss: 0.0079 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0075 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 6s 161ms/step - loss: 0.0185 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0100 - accuracy: 0.9969 - top-5-accuracy: 1.0000
# Test accuracy: 99.69%
# Test top 5 accuracy: 100.0%
# CPU times: user 35min 41s, sys: 40.4 s, total: 36min 22s
# Wall time: 25min 28s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 334 ms, sys: 43.2 ms, total: 377 ms
# Wall time: 341 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 1s 10ms/step
# CPU times: user 897 ms, sys: 17.8 ms, total: 915 ms
# Wall time: 984 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 7.87 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[303   1   1]
#  [  0 333   0]
#  [  0   1 420]]
# CPU times: user 225 ms, sys: 117 ms, total: 342 ms
# Wall time: 212 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      0.99      1.00       305
#          Downy Mildew       0.99      1.00      1.00       333
#             Leaf Spot       1.00      1.00      1.00       421
#
#              accuracy                           1.00      1059
#             macro avg       1.00      1.00      1.00      1059
#          weighted avg       1.00      1.00      1.00      1059
#
# CPU times: user 7.39 ms, sys: 0 ns, total: 7.39 ms
# Wall time: 7.4 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 0s 11ms/step
# CPU times: user 378 ms, sys: 15 ms, total: 393 ms
# Wall time: 366 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 7.87 µs

# %%
# %%time
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   0]
#  [  0 202   1]
#  [  0   1 250]]
# CPU times: user 209 ms, sys: 111 ms, total: 320 ms
# Wall time: 195 ms

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       200
#          Downy Mildew       1.00      1.00      1.00       203
#             Leaf Spot       1.00      1.00      1.00       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 7 ms, sys: 0 ns, total: 7 ms
# Wall time: 7.54 ms
