# %% [markdown]
# This code is licensed to University of Quesland. You are not permitted to share or distribute this code**

# %%
# %%time
### GPU configuration
! nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# CPU times: user 5.55 ms, sys: 1.08 ms, total: 6.62 ms
# Wall time: 112 ms

# %%
# %%time
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CPU times: user 88.5 ms, sys: 7.99 ms, total: 96.4 ms
# Wall time: 8.64 s

# %%
# %%time
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# CPU times: user 55.5 ms, sys: 10.1 ms, total: 65.5 ms
# Wall time: 7.15 s

# %%
# %%time
# !pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.3.18)
# CPU times: user 84.9 ms, sys: 7.04 ms, total: 91.9 ms
# Wall time: 9.37 s

# %%
# %%time
import cv2
import numpy as np
import glob
import os
# Out:
# CPU times: user 33 µs, sys: 1e+03 ns, total: 34 µs
# Wall time: 49.4 µs

# %%
# %%time
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf
# Out:
# CPU times: user 144 µs, sys: 7 µs, total: 151 µs
# Wall time: 156 µs

# %%
# %%time
import os
import warnings
import itertools
import cv2
import seaborn as sns
import pandas as pd
import numpy  as np
from PIL import Image
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter

import tensorflow as tf
import tensorflow_addons as tfa
import visualkeras
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# CPU times: user 3.85 ms, sys: 0 ns, total: 3.85 ms
# Wall time: 4.64 ms

# %%
# %%time
from matplotlib import pyplot as plt
# Out:
# CPU times: user 10 µs, sys: 0 ns, total: 10 µs
# Wall time: 14.3 µs

# %%
# %%time
labels = ["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]
img_size = 64
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 10.3 µs

# %%
# %%time
data_dir = get_data("/content/drive/MyDrive/Luffa Aegyptiaca")
# Out:
# CPU times: user 24min 46s, sys: 2min 30s, total: 27min 17s
# Wall time: 28min 44s

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in
# %%time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import time
import cv2
import glob
import matplotlib.pyplot as plt
# Out:
# CPU times: user 19 µs, sys: 1e+03 ns, total: 20 µs
# Wall time: 23.4 µs

# %%
# %%time
image_names = glob.glob(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca', '*', '*'))
print("Total number of training images: ", len(image_names))

# Make image_names a pandas Series object
image_names = pd.Series(image_names)
# Out:
# Total number of training images:  6531
# CPU times: user 36.7 ms, sys: 3.11 ms, total: 39.8 ms
# Wall time: 197 ms

# %%
# %%time
# train_df: a dataframe with 2 field: Filename, ClassId
data_df = pd.DataFrame()

# generate Filename field
data_df['Filename'] = image_names.map(lambda img_name: img_name.split("/")[-1])

# generate ClassId field
data_df['ClassId'] = image_names.map(lambda img_name: (img_name.split("/")[-2]))

data_df.head()
# Out:
# CPU times: user 13.1 ms, sys: 886 µs, total: 14 ms
# Wall time: 26.8 ms
#                            Filename                ClassId
# 0  Cucumber-Mosaic-Virus (1078).jpg  Cucumber Mosaic Virus
# 1  Cucumber-Mosaic-Virus (1217).jpg  Cucumber Mosaic Virus
# 2   Cucumber-Mosaic-Virus (781).jpg  Cucumber Mosaic Virus
# 3  Cucumber-Mosaic-Virus (1018).jpg  Cucumber Mosaic Virus
# 4   Cucumber-Mosaic-Virus (749).jpg  Cucumber Mosaic Virus

# %%
# %%time
plot_df = data_df.sample(min(9, len(data_df))).reset_index()

plt.figure(figsize=(10, 10))

for i in range(9):
    img_name = plot_df.loc[i, 'Filename']
    label_str = (plot_df.loc[i, 'ClassId'])
    plt.subplot(3,3,i+1)
    plt.imshow(plt.imread(os.path.join('/content/drive/MyDrive/Luffa Aegyptiaca',label_str, img_name)))
    plt.title(label_str)
    plt.xticks([])
    plt.yticks([])
# Out:
# CPU times: user 809 ms, sys: 354 ms, total: 1.16 s
# Wall time: 1.27 s

# %%
# %%time
class_id_distribution = data_df['ClassId'].value_counts()
class_id_distribution.head(10)
# Out:
# CPU times: user 1.41 ms, sys: 1.9 ms, total: 3.31 ms
# Wall time: 7.03 ms
# Leaf Spot                2504
# Downy Mildew             2023
# Cucumber Mosaic Virus    2004
# Name: ClassId, dtype: int64

# %%
# %%time
plt.figure(figsize=(5,5))
plt.xticks(np.arange(43))
plt.bar(class_id_distribution.index, class_id_distribution.values)
# Out:
# CPU times: user 99.6 ms, sys: 1.04 ms, total: 101 ms
# Wall time: 317 ms
# <BarContainer object of 3 artists>

# %%
# %%time
plt.figure(figsize = (5,5))
plt.imshow(data_dir[1][0])
plt.title(labels[data_dir[0][1]])
# Out:
# CPU times: user 27.6 ms, sys: 1.91 ms, total: 29.5 ms
# Wall time: 87 ms
# Text(0.5, 1.0, 'Cucumber Mosaic Virus')

# %%
# %%time
X = []
Y = []


for feature, label in data_dir:
  X.append(feature)
  Y.append(label)
X = np.array(X) / 255
X.reshape(-1, img_size, img_size, 1)
Y = np.array(Y)
# Out:
# CPU times: user 71.3 ms, sys: 304 ms, total: 375 ms
# Wall time: 1.05 s

# %%
# %%time
print(X.shape)
# Out:
# (6531, 64, 64, 3)
# CPU times: user 40 µs, sys: 0 ns, total: 40 µs
# Wall time: 43.2 µs

# %%
# %%time
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(X, Y, test_size=0.10, stratify=Y, random_state=42)
# Out:
# CPU times: user 73.5 ms, sys: 412 ms, total: 485 ms
# Wall time: 1.21 s

# %%
# %%time
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train,
    test_size=0.18, random_state= 8) # 0.25 x 0.8 = 0.2
# Out:
# CPU times: user 106 ms, sys: 420 ms, total: 526 ms
# Wall time: 1.78 s

# %%
# %%time
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape} - y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (4819, 64, 64, 3) - y_train shape: (4819,)
# x_val shape: (1058, 64, 64, 3) - y_val shape: (1058,)
# x_test shape: (654, 64, 64, 3) - y_test shape: (654,)
# CPU times: user 1.43 ms, sys: 0 ns, total: 1.43 ms
# Wall time: 1.43 ms

# %%
# %%time
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# CPU times: user 117 ms, sys: 40 ms, total: 157 ms
# Wall time: 13.3 s

# %%
# %%time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# CPU times: user 19 µs, sys: 1e+03 ns, total: 20 µs
# Wall time: 23.8 µs

# %%
# %%time
num_classes = 3
input_shape = (64, 64, 3)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs

# %%
# %%time
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 250
image_size = 64  # We'll resize input images to this size
patch_size = 12  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 3
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]
# Out:
# CPU times: user 11 µs, sys: 0 ns, total: 11 µs
# Wall time: 14.5 µs

# %%
# %%time
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# CPU times: user 1.19 s, sys: 551 ms, total: 1.74 s
# Wall time: 2.73 s

# %%
# %%time
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 5.96 µs

# %%
# %%time
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
# Out:
# CPU times: user 41 µs, sys: 2 µs, total: 43 µs
# Wall time: 48.2 µs

# %%
# %%time
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 64 X 64
# Patch size: 12 X 12
# Patches per image: 25
# Elements per patch: 432
# CPU times: user 358 ms, sys: 23.9 ms, total: 382 ms
# Wall time: 395 ms

# %%
# %%time
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
# Out:
# CPU times: user 0 ns, sys: 85 µs, total: 85 µs
# Wall time: 46.3 µs

# %%
# %%time
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
# Out:
# CPU times: user 0 ns, sys: 418 µs, total: 418 µs
# Wall time: 295 µs

# %%
# %%time
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    model.summary()

    checkpoint_filepath = "/content/drive/MyDrive/model/model64_12.h5"
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,

        lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7),


# stop learining as metric on validatopn stop increasing
        early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_data=(x_val, y_val),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history
# Out:
# CPU times: user 8 µs, sys: 1 µs, total: 9 µs
# Wall time: 6.44 µs

# %%
# %%time
vit_classifier = create_vit_classifier()
vit_history = run_experiment(vit_classifier)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7f4f1b891570>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7f4f1b891570>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Patches.call of <__main__.Patches object at 0x7f4f1b891570>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method Patches.call of <__main__.Patches object at 0x7f4f1b891570>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7f4f1b752d10>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7f4f1b752d10>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7f4f1b752d10>> and will run it as-is.
# Cause: Unable to locate the source code of <bound method PatchEncoder.call of <__main__.PatchEncoder object at 0x7f4f1b752d10>>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 64, 64, 3)            7         ['input_2[0][0]']
#  ial)
#
#  patches_3 (Patches)         (None, None, 432)            0         ['data_augmentation[0][0]']
#
#  patch_encoder_1 (PatchEnco  (None, 25, 64)               29312     ['patches_3[0][0]']
#  der)
#
#  layer_normalization_3 (Lay  (None, 25, 64)               128       ['patch_encoder_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 25, 64)               49792     ['layer_normalization_3[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_3[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 25, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'patch_encoder_1[0][0]']
#
#  layer_normalization_4 (Lay  (None, 25, 64)               128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 25, 128)              8320      ['layer_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_5 (Dropout)         (None, 25, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 25, 64)               8256      ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)         (None, 25, 64)               0         ['dense_8[0][0]']
#
#  add_3 (Add)                 (None, 25, 64)               0         ['dropout_6[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_5 (Lay  (None, 25, 64)               128       ['add_3[0][0]']
#  erNormalization)
#
#  flatten_1 (Flatten)         (None, 1600)                 0         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 1600)                 0         ['flatten_1[0][0]']
#
#  dense_9 (Dense)             (None, 2048)                 3278848   ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)         (None, 2048)                 0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 1024)                 2098176   ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 1024)                 0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 3)                    3075      ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 5476170 (20.89 MB)
# Trainable params: 5476163 (20.89 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/250
# 38/38 [==============================] - 13s 282ms/step - loss: 1.1802 - accuracy: 0.6350 - top-5-accuracy: 1.0000 - val_loss: 0.6581 - val_accuracy: 0.7363 - val_top-5-accuracy: 1.0000
# Epoch 2/250
# 38/38 [==============================] - 11s 281ms/step - loss: 0.4995 - accuracy: 0.8045 - top-5-accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.8715 - val_top-5-accuracy: 1.0000
# Epoch 3/250
# 38/38 [==============================] - 10s 256ms/step - loss: 0.3771 - accuracy: 0.8560 - top-5-accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9225 - val_top-5-accuracy: 1.0000
# Epoch 4/250
# 38/38 [==============================] - 11s 277ms/step - loss: 0.2930 - accuracy: 0.8877 - top-5-accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9414 - val_top-5-accuracy: 1.0000
# Epoch 5/250
# 38/38 [==============================] - 11s 287ms/step - loss: 0.2066 - accuracy: 0.9211 - top-5-accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9660 - val_top-5-accuracy: 1.0000
# Epoch 6/250
# 38/38 [==============================] - 17s 455ms/step - loss: 0.1944 - accuracy: 0.9263 - top-5-accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9679 - val_top-5-accuracy: 1.0000
# Epoch 7/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.1739 - accuracy: 0.9396 - top-5-accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9820 - val_top-5-accuracy: 1.0000
# Epoch 8/250
# 38/38 [==============================] - 10s 267ms/step - loss: 0.1741 - accuracy: 0.9367 - top-5-accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9783 - val_top-5-accuracy: 1.0000
# Epoch 9/250
# 38/38 [==============================] - 9s 238ms/step - loss: 0.1467 - accuracy: 0.9475 - top-5-accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 10/250
# 38/38 [==============================] - 11s 290ms/step - loss: 0.1237 - accuracy: 0.9575 - top-5-accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9905 - val_top-5-accuracy: 1.0000
# Epoch 11/250
# 38/38 [==============================] - 10s 267ms/step - loss: 0.0923 - accuracy: 0.9680 - top-5-accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9905 - val_top-5-accuracy: 1.0000
# Epoch 12/250
# 38/38 [==============================] - 10s 267ms/step - loss: 0.
250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0229 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 207/250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0096 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 208/250
# 38/38 [==============================] - 10s 262ms/step - loss: 0.0149 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 209/250
# 38/38 [==============================] - 10s 249ms/step - loss: 0.0189 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 210/250
# 38/38 [==============================] - 10s 270ms/step - loss: 0.0180 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 211/250
# 38/38 [==============================] - 10s 270ms/step - loss: 0.0209 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 212/250
# 38/38 [==============================] - 9s 240ms/step - loss: 0.0222 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 213/250
# 38/38 [==============================] - 10s 259ms/step - loss: 0.0185 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 214/250
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0095 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 215/250
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0108 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 216/250
# 38/38 [==============================] - 9s 242ms/step - loss: 0.0144 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 217/250
# 38/38 [==============================] - 10s 268ms/step - loss: 0.0105 - accuracy: 0.9981 - top-5-accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 218/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0058 - accuracy: 0.9990 - top-5-accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 219/250
# 38/38 [==============================] - 10s 275ms/step - loss: 0.0130 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 220/250
# 38/38 [==============================] - 9s 242ms/step - loss: 0.0088 - accuracy: 0.9977 - top-5-accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 221/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0150 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 222/250
# 38/38 [==============================] - 10s 270ms/step - loss: 0.0161 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 223/250
# 38/38 [==============================] - 10s 269ms/step - loss: 0.0047 - accuracy: 0.9983 - top-5-accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 224/250
# 38/38 [==============================] - 9s 240ms/step - loss: 0.0108 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 225/250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0079 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 226/250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0105 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 227/250
# 38/38 [==============================] - 10s 268ms/step - loss: 0.0123 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 228/250
# 38/38 [==============================] - 9s 245ms/step - loss: 0.0223 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 229/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0193 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 230/250
# 38/38 [==============================] - 10s 265ms/step - loss: 0.0170 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 231/250
# 38/38 [==============================] - 9s 242ms/step - loss: 0.0141 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 232/250
# 38/38 [==============================] - 10s 260ms/step - loss: 0.0153 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 233/250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0088 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 234/250
# 38/38 [==============================] - 10s 268ms/step - loss: 0.0049 - accuracy: 0.9985 - top-5-accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 235/250
# 38/38 [==============================] - 9s 237ms/step - loss: 0.0240 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 236/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0304 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 237/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0212 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 238/250
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0227 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 239/250
# 38/38 [==============================] - 9s 237ms/step - loss: 0.0227 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 240/250
# 38/38 [==============================] - 10s 271ms/step - loss: 0.0157 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9915 - val_top-5-accuracy: 1.0000
# Epoch 241/250
# 38/38 [==============================] - 12s 320ms/step - loss: 0.0142 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 242/250
# 38/38 [==============================] - 11s 284ms/step - loss: 0.0065 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9962 - val_top-5-accuracy: 1.0000
# Epoch 243/250
# 38/38 [==============================] - 9s 242ms/step - loss: 0.0082 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 244/250
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0123 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9972 - val_top-5-accuracy: 1.0000
# Epoch 245/250
# 38/38 [==============================] - 10s 268ms/step - loss: 0.0075 - accuracy: 0.9983 - top-5-accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9934 - val_top-5-accuracy: 1.0000
# Epoch 246/250
# 38/38 [==============================] - 10s 277ms/step - loss: 0.0076 - accuracy: 0.9985 - top-5-accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9924 - val_top-5-accuracy: 1.0000
# Epoch 247/250
# 38/38 [==============================] - 9s 238ms/step - loss: 0.0080 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 248/250
# 38/38 [==============================] - 10s 272ms/step - loss: 0.0243 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9943 - val_top-5-accuracy: 1.0000
# Epoch 249/250
# 38/38 [==============================] - 10s 273ms/step - loss: 0.0132 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# Epoch 250/250
# 38/38 [==============================] - 10s 274ms/step - loss: 0.0166 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9953 - val_top-5-accuracy: 1.0000
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0096 - accuracy: 0.9954 - top-5-accuracy: 1.0000
# Test accuracy: 99.54%
# Test top 5 accuracy: 100.0%
# CPU times: user 1h 3min 56s, sys: 1min 3s, total: 1h 4min 59s
# Wall time: 42min 30s

# %%
# %%time
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(vit_history.history['loss'], label='Training Loss')
plt.plot(vit_history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(vit_history.history['accuracy'], label='Training Accuracy')
plt.plot(vit_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# CPU times: user 309 ms, sys: 111 ms, total: 420 ms
# Wall time: 310 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_val)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 34/34 [==============================] - 1s 17ms/step
# CPU times: user 1.16 s, sys: 111 ms, total: 1.27 s
# Wall time: 948 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 11 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_val, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[319   0   1]
#  [  0 311   1]
#  [  0   1 425]]
# CPU times: user 246 ms, sys: 126 ms, total: 372 ms
# Wall time: 251 ms

# %%
# %%time
print(classification_report(y_val, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       320
#          Downy Mildew       1.00      1.00      1.00       312
#             Leaf Spot       1.00      1.00      1.00       426
#
#              accuracy                           1.00      1058
#             macro avg       1.00      1.00      1.00      1058
#          weighted avg       1.00      1.00      1.00      1058
#
# CPU times: user 7.75 ms, sys: 1.03 ms, total: 8.78 ms
# Wall time: 9.12 ms

# %%
# %%time
vit_predictions = vit_classifier.predict(x_test)
vit_y_pred = [np.argmax(probas) for probas in vit_predictions]
# Out:
# 21/21 [==============================] - 0s 18ms/step
# CPU times: user 610 ms, sys: 41.2 ms, total: 651 ms
# Wall time: 465 ms

# %%
# %%time
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 8.82 µs

# %%
# compute confusion matrix
# %%time
cnf_matrix = confusion_matrix(y_test, vit_y_pred)
np.set_printoptions(precision=2)
# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"], title='Normalized confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[200   0   1]
#  [  0 200   2]
#  [  0   0 251]]
# CPU times: user 218 ms, sys: 124 ms, total: 342 ms
# Wall time: 235 ms

# %%
# %%time
print(classification_report(y_test, vit_y_pred, target_names=["Cucumber Mosaic Virus", "Downy Mildew", "Leaf Spot"]))
# Out:
#                        precision    recall  f1-score   support
#
# Cucumber Mosaic Virus       1.00      1.00      1.00       201
#          Downy Mildew       1.00      0.99      1.00       202
#             Leaf Spot       0.99      1.00      0.99       251
#
#              accuracy                           1.00       654
#             macro avg       1.00      1.00      1.00       654
#          weighted avg       1.00      1.00      1.00       654
#
# CPU times: user 5.97 ms, sys: 0 ns, total: 5.97 ms
# Wall time: 6.17 ms
